# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download  airbus-ship-detection
# Out:
# Downloading airbus-ship-detection.zip to /content
# 100% 28.6G/28.6G [03:28<00:00, 116MB/s]
# 100% 28.6G/28.6G [03:28<00:00, 147MB/s]

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %%
! unzip /content/airbus-ship-detection.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: train_v2/f9775b70e.jpg
#   inflating: train_v2/f977a470c.jpg
#   inflating: train_v2/f9780bfaf.jpg
#   inflating: train_v2/f9782bdfe.jpg
#   inflating: train_v2/f9785ca49.jpg
#   inflating: train_v2/f9785e462.jpg
#   inflating: train_v2/f97a719d5.jpg
#   inflating: train_v2/f97afa376.jpg
#   inflating: train_v2/f97b85e3e.jpg
#   inflating: train_v2/f97bd0b11.jpg
#   inflating: train_v2/f97bd6b80.jpg
#   inflating: train_v2/f97bfb1b2.jpg
#   inflating: train_v2/f97c8cbbe.jpg
#   inflating: train_v2/f97cdd397.jpg
#   inflating: train_v2/f97d92e1e.jpg
#   inflating: train_v2/f97da9e70.jpg
#   inflating: train_v2/f97e843d3.jpg
#   inflating: train_v2/f97e961f2.jpg
#   inflating: train_v2/f97e96c68.jpg
#   inflating: train_v2/f97f63ae1.jpg
#   inflating: train_v2/f97f80839.jpg
#   inflating: train_v2/f97f83438.jpg
#   inflating: train_v2/f97fab9ad.jpg
#   inflating: train_v2/f97fd4915.jpg
#   inflating: train_v2/f9801bc03.jpg
#   inflating: train_v2/f98022dd0.jpg
#   inflating: train_v2/f9805a2f6.jpg
#   inflating: train_v2/f9805d413.jpg
#   inflating: train_v2/f9818a4fd.jpg
#   inflating: train_v2/f9821ea00.jpg
#   inflating: train_v2/f9823212e.jpg
#   inflating: train_v2/f98274f5b.jpg
#   inflating: train_v2/f98288a56.jpg
#   inflating: train_v2/f982932f1.jpg
#   inflating: train_v2/f982af57b.jpg
#   inflating: train_v2/f982ed254.jpg
#   inflating: train_v2/f98359b0c.jpg
#   inflating: train_v2/f984982f5.jpg
#   inflating: train_v2/f984ce70b.jpg
#   inflating: train_v2/f984e9401.jpg
#   inflating: train_v2/f98534ba2.jpg
#   inflating: train_v2/f986f07b4.jpg
#   inflating: train_v2/f98728658.jpg
#   inflating: train_v2/f9872f640.jpg
#   inflating: train_v2/f987a502b.jpg
#   inflating: train_v2/f987a716d.jpg
#   inflating: train_v2/f987a842b.jpg
#   inflating: train_v2/f987d9aae.jpg
#   inflating: train_v2/f9883ef23.jpg
#   inflating: train_v2/f988d1d87.jpg
#   inflating: train_v2/f98a2905c.jpg
#   inflating: train_v2/f98b6bb8c.jpg
#   inflating: train_v2/f98ba09af.jpg
#   inflating: train_v2/f98be7520.jpg
#   inflating: train_v2/f98c4d2c7.jpg
#   inflating: train_v2/f98c5cd72.jpg
#   inflating: train_v2/f98cae212.jpg
#   inflating: train_v2/f98cba392.jpg
#   inflating: train_v2/f98cc205e.jpg
#   inflating: train_v2/f98d30216.jpg
#   inflating: train_v2/f98d3041c.jpg
#   inflating: train_v2/f98e1a743.jpg
#   inflating: train_v2/f98e25282.jpg
#   inflating: train_v2/f98e66e68.jpg
#   inflating: train_v2/f98f1b0de.jpg
#   inflating: train_v2/f98f3e2c4.jpg
#   inflating: train_v2/f98f65d64.jpg
#   inflating: train_v2/f9913a522.jpg
#   inflating: train_v2/f991598b6.jpg
#   inflating: train_v2/f99165d4f.jpg
#   inflating: train_v2/f991dd002.jpg
#   inflating: train_v2/f9927e39d.jpg
#   inflating: train_v2/f99378eac.jpg
#   inflating: train_v2/f993ee262.jpg
#   inflating: train_v2/f9947f705.jpg
#   inflating: train_v2/f994d6598.jpg
#   inflating: train_v2/f99525c0f.jpg
#   inflating: train_v2/f995498d2.jpg
#   inflating: train_v2/f995c3914.jpg
#   inflating: train_v2/f995dd98e.jpg
#   inflating: train_v2/f995e7f25.jpg
#   inflating: train_v2/f995ff3ad.jpg
#   inflating: train_v2/f9969703e.jpg
#   inflating: train_v2/f996a2e38.jpg
#   inflating: train_v2/f99777cf3.jpg
#   inflating: train_v2/f99793e48.jpg
#   inflating: train_v2/f997fa564.jpg
#   inflating: train_v2/f9992e79f.jpg
#   inflating: train_v2/f999e81c2.jpg
#   inflating: train_v2/f999ed541.jpg
#   inflating: train_v2/f999ee8f8.jpg
#   inflating: train_v2/f99a1fe6a.jpg
#   inflating: train_v2/f99a4585d.jpg
#   inflating: train_v2/f99a64ae4.jpg
#   inflating: train_v2/f99a8fb08.jpg
#   inflating: train_v2/f99af67f9.jpg
#   inflating: train_v2/f99afa15f.jpg
#   inflating: train_v2/f99b10499.jpg
#   inflating: train_v2/f99b74595.jpg
#   inflating: train_v2/f99baa9fa.jpg
#   inflating: train_v2/f99bcad7d.jpg
#   inflating: train_v2/f99bd3c72.jpg
#   inflating: train_v2/f99bea7eb.jpg
#   inflating: train_v2/f99c66c0c.jpg
#   inflating: train_v2/f99d11ebf.jpg
#   inflating: train_v2/f99d46651.jpg
#   inflating: train_v2/f99d51498.jpg
#   inflating: train_v2/f99d8d787.jpg
#   inflating: train_v2/f99e2b574.jpg
#   inflating: train_v2/f99e55952.jpg
#   inflating: train_v2/f99e8b803.jpg
#   inflating: train_v2/f99ea8ee4.jpg
#   inflating: train_v2/f99f35a69.jpg
#   inflating: train_v2/f99f4ae29.jpg
#   inflating: train_v2/f99f6bae1.jpg
#   inflating: train_v2/f99f81c35.jpg
#   inflating: train_v2/f9a007df1.jpg
#   inflating: train_v2/f9a05aa82.jpg
#   inflating: train_v2/f9a0835d8.jpg
#   inflating: train_v2/f9a0c116e.jpg
#   inflating: train_v2/f9a18a80d.jpg
#   inflating: train_v2/f9a22944b.jpg
#   inflating: train_v2/f9a26098d.jpg
#   inflating: train_v2/f9a269243.jpg
#   inflating: train_v2/f9a320728.jpg
#   inflating: train_v2/f9a322dab.jpg
#   inflating: train_v2/f9a3e61fd.jpg
#   inflating: train_v2/f9a53f2a7.jpg
#   inflating: train_v2/f9a603aaa.jpg
#   inflating: train_v2/f9a604422.jpg
#   inflating: train_v2/f9a6f2c77.jpg
#   inflating: train_v2/f9a70f711.jpg
#   inflating: train_v2/f9a7cc695.jpg
#   inflating: train_v2/f9a7f3b7e.jpg
#   inflating: train_v2/f9a81a82b.jpg
#   inflating: train_v2/f9a82faa9.jpg
#   inflating: train_v2/f9a885f01.jpg
#   inflating: train_v2/f9a8d3eef.jpg
#   inflating: train_v2/f9a9197bf.jpg
#   inflating: train_v2/f9a92bf1f.jpg
#   inflating: train_v2/f9a94f6b3.jpg
#   inflating: train_v2/f9a959150.jpg
#   inflating: train_v2/f9a984ead.jpg
#   inflating: train_v2/f9a9e7be0.jpg
#   inflating: train_v2/f9aa3891f.jpg
#   inflating: train_v2/f9ab1d04a.jpg
#   inflating: train_v2/f9ab280c4.jpg
#   inflating: train_v2/f9ab4440e.jpg
#   inflating: train_v2/f9ab674c6.jpg
#   inflating: train_v2/f9ab691e3.jpg
#   inflating: train_v2/f9ab83a48.jpg
#   inflating: train_v2/f9ab9774a.jpg
#   inflating: train_v2/f9aba8c24.jpg
#   inflating: train_v2/f9abb49b5.jpg
#   inflating: train_v2/f9ac3709b.jpg
#   inflating: train_v2/f9ac544b3.jpg
#   inflating: train_v2/f9ac9b552.jpg
#   inflating: train_v2/f9ac9feeb.jpg
#   inflating: train_v2/f9ad27444.jpg
#   inflating: train_v2/f9ad2c62d.jpg
#   inflating: train_v2/f9ad7fe64.jpg
#   inflating: train_v2/f9ad9d12c.jpg
#   inflating: train_v2/f9adc5fa2.jpg
#   inflating: train_v2/f9adcac73.jpg
#   inflating: train_v2/f9adec1ec.jpg
#   inflating: train_v2/f9ae79d51.jpg
#   inflating: train_v2/f9aea36cd.jpg
#   inflating: train_v2/f9af2bd6b.jpg
#   inflating: train_v2/f9af3bef0.jpg
#   inflating: train_v2/f9b004e32.jpg
#   inflating: train_v2/f9b00bd14.jpg
#   inflating: train_v2/f9b076112.jpg
#   inflating: train_v2/f9b09fb96.jpg
#   inflating: train_v2/f9b0fb2d0.jpg
#   inflating: train_v2/f9b1fdd34.jpg
#   inflating: train_v2/f9b20251a.jpg
#   inflating: train_v2/f9b23c85b.jpg
#   inflating: train_v2/f9b25f226.jpg
#   inflating: train_v2/f9b2620e9.jpg
#   inflating: train_v2/f9b26fae9.jpg
#   inflating: train_v2/f9b2aaee5.jpg
#   inflating: train_v2/f9b2e0ffe.jpg
#   inflating: train_v2/f9b36f587.jpg
#   inflating: train_v2/f9b414940.jpg
#   inflating: train_v2/f9b42e189.jpg
#   inflating: train_v2/f9b469415.jpg
#   inflating: train_v2/f9b55bb52.jpg
#   inflating: train_v2/f9b587330.jpg
#   inflating: train_v2/f9b5a20e9.jpg
#   inflating: train_v2/f9b5ae24e.jpg
#   inflating: train_v2/f9b680776.jpg
#   inflating: train_v2/f9b72db35.jpg
#   inflating: train_v2/f9b73144d.jpg
#   inflating: train_v2/f9b755c24.jpg
#   inflating: train_v2/f9b7a02c2.jpg
#   inflating: train_v2/f9b7c5567.jpg
#   inflating: train_v2/f9b809c95.jpg
#   inflating: train_v2/f9b80dfd8.jpg
#   inflating: train_v2/f9b8aac11.jpg
#   inflating: train_v2/f9b920092.jpg
#   inflating: train_v2/f9ba782cd.jpg
#   inflating: train_v2/f9ba8cbc2.jpg
#   inflating: train_v2/f9ba9739e.jpg
#   inflating: train_v2/f9babe881.jpg
#   inflating: train_v2/f9bb8ef24.jpg
#   inflating: train_v2/f9bbe2327.jpg
#   inflating: train_v2/f9bbf39cb.jpg
#   inflating: train_v2/f9bc1b37c.jpg
#   inflating: train_v2/f9bc7e506.jpg
#   inflating: train_v2/f9bc8b405.jpg
#   inflating: train_v2/f9bc9f915.jpg
#   inflating: train_v2/f9bcadd59.jpg
#   inflating: train_v2/f9bcb37bf.jpg
#   inflating: train_v2/f9bcb6811.jpg
#   inflating: train_v2/f9bce343e.jpg
#   inflating: train_v2/f9bce9370.jpg
#   inflating: train_v2/f9bcee9c9.jpg
#   inflating: train_v2/f9bd0eaa9.jpg
#   inflating: train_v2/f9bdee7d4.jpg
#   inflating: train_v2/f9be5c8f3.jpg
#   inflating: train_v2/f9be5e669.jpg
#   inflating: train_v2/f9be636e1.jpg
#   inflating: train_v2/f9be746e6.jpg
#   inflating: train_v2/f9be7b574.jpg
#   inflating: train_v2/f9beebd25.jpg
#   inflating: train_v2/f9bf37080.jpg
#   inflating: train_v2/f9c0ed34d.jpg
#   inflating: train_v2/f9c182138.jpg
#   inflating: train_v2/f9c1bb4ab.jpg
#   inflating: train_v2/f9c21468f.jpg
#   inflating: train_v2/f9c257f44.jpg
#   inflating: train_v2/f9c2759ee.jpg
#   inflating: train_v2/f9c30c717.jpg
#   inflating: train_v2/f9c340b4a.jpg
#   inflating: train_v2/f9c34194a.jpg
#   inflating: train_v2/f9c3565c1.jpg
#   inflating: train_v2/f9c47d3b1.jpg
#   inflating: train_v2/f9c50f40e.jpg
#   inflating: train_v2/f9c55e67f.jpg
#   inflating: train_v2/f9c5c372a.jpg
#   inflating: train_v2/f9c5ec37c.jpg
#   inflating: train_v2/f9c61605c.jpg
#   inflating: train_v2/f9c6702e4.jpg
#   inflating: train_v2/f9c677352.jpg
#   inflating: train_v2/f9c69d93b.jpg
#   inflating: train_v2/f9c6df786.jpg
#   inflating: train_v2/f9c7ab9d2.jpg
#   inflating: train_v2/f9c8285b1.jpg
#   inflating: train_v2/f9c861de3.jpg
#   inflating: train_v2/f9c8db31c.jpg
#   inflating: train_v2/f9c903a4a.jpg
#   inflating: train_v2/f9c94d855.jpg
#   inflating: train_v2/f9c95ae14.jpg
#   inflating: train_v2/f9c966f2c.jpg
#   inflating: train_v2/f9c96f26c.jpg
#   inflating: train_v2/f9ca33e2b.jpg
#   inflating: train_v2/f9ca60222.jpg
#   inflating: train_v2/f9ca79715.jpg
#   inflating: train_v2/f9cb02f02.jpg
#   inflating: train_v2/f9cbb2ac9.jpg
#   inflating: train_v2/f9cd00c50.jpg
#   inflating: train_v2/f9cd23b41.jpg
#   inflating: train_v2/f9cd55015.jpg
#   inflating: train_v2/f9ce11573.jpg
#   inflating: train_v2/f9cf38397.jpg
#   inflating: train_v2/f9cf56324.jpg
#   inflating: train_v2/f9cf9a6d6.jpg
#   inflating: train_v2/f9cfb3893.jpg
#   inflating: train_v2/f9cfb77eb.jpg
#   inflating: train_v2/f9cfce65e.jpg
#   inflating: train_v2/f9cfdedcc.jpg
#   inflating: train_v2/f9d024d68.jpg
#   inflating: train_v2/f9d072da1.jpg
#   inflating: train_v2/f9d0da010.jpg
#   inflating: train_v2/f9d151027.jpg
#   inflating: train_v2/f9d155c58.jpg
#   inflating: train_v2/f9d16725b.jpg
#   inflating: train_v2/f9d1832f2.jpg
#   inflating: train_v2/f9d1b14e2.jpg
#   inflating: train_v2/f9d1bcc37.jpg
#   inflating: train_v2/f9d1be94a.jpg
#   inflating: train_v2/f9d1d1594.jpg
#   inflating: train_v2/f9d24b029.jpg
#   inflating: train_v2/f9d2e9b3c.jpg
#   inflating: train_v2/f9d2ec05e.jpg
#   inflating: train_v2/f9d310c76.jpg
#   inflating: train_v2/f9d350d81.jpg
#   inflating: train_v2/f9d3821cf.jpg
#   inflating: train_v2/f9d3fbe66.jpg
#   inflating: train_v2/f9d441a11.jpg
#   inflating: train_v2/f9d4b6d42.jpg
#   inflating: train_v2/f9d4b9343.jpg
#   inflating: train_v2/f9d4e041e.jpg
#   inflating: train_v2/f9d4e7eeb.jpg
#   inflating: train_v2/f9d519773.jpg
#   inflating: train_v2/f9d556304.jpg
#   inflating: train_v2/f9d56edd1.jpg
#   inflating: train_v2/f9d5e2b47.jpg
#   inflating: train_v2/f9d670a71.jpg
#   inflating: train_v2/f9d684284.jpg
#   inflating: train_v2/f9d728b2f.jpg
#   inflating: train_v2/f9d782301.jpg
#   inflating: train_v2/f9d7edf67.jpg
#   inflating: train_v2/f9d811889.jpg
#   inflating: train_v2/f9d86f5a5.jpg
#   inflating: train_v2/f9d8f300f.jpg
#   inflating: train_v2/f9d9e22be.jpg
#   inflating: train_v2/f9da5df17.jpg
#   inflating: train_v2/f9daf268e.jpg
#   inflating: train_v2/f9db69b4b.jpg
#   inflating: train_v2/f9db7f893.jpg
#   inflating: train_v2/f9db9abed.jpg
#   inflating: train_v2/f9dcac798.jpg
#   inflating: train_v2/f9dcf5f74.jpg
#   inflating: train_v2/f9dd32df1.jpg
#   inflating: train_v2/f9de762a5.jpg
#   inflating: train_v2/f9de80c5b.jpg
#   inflating: train_v2/f9dec055e.jpg
#   inflating: train_v2/f9dedb669.jpg
#   inflating: train_v2/f9df2eeb2.jpg
#   inflating: train_v2/f9df687e7.jpg
#   inflating: train_v2/f9df6fe66.jpg
#   inflating: train_v2/f9df775f7.jpg
#   inflating: train_v2/f9dfbbd15.jpg
#   inflating: train_v2/f9e108bd0.jpg
#   inflating: train_v2/f9e159a37.jpg
#   inflating: train_v2/f9e18a002.jpg
#   inflating: train_v2/f9e18c55b.jpg
#   inflating: train_v2/f9e1a302d.jpg
#   inflating: train_v2/f9e1ed637.jpg
#   inflating: train_v2/f9e2422ae.jpg
#   inflating: train_v2/f9e24b150.jpg
#   inflating: train_v2/f9e2b5cef.jpg
#   inflating: train_v2/f9e3320a6.jpg
#   inflating: train_v2/f9e356b73.jpg
#   inflating: train_v2/f9e35fee2.jpg
#   inflating: train_v2/f9e43dddd.jpg
#   inflating: train_v2/f9e44b652.jpg
#   inflating: train_v2/f9e44d894.jpg
#   inflating: train_v2/f9e47e599.jpg
#   inflating: train_v2/f9e526dc2.jpg
#   inflating: train_v2/f9e56e73d.jpg
#   inflating: train_v2/f9e5df355.jpg
#   inflating: train_v2/f9e5e8b0d.jpg
#   inflating: train_v2/f9e5eb506.jpg
#   inflating: train_v2/f9e60b8ea.jpg
#   inflating: train_v2/f9e66a6fe.jpg
#   inflating: train_v2/f9e6afc1a.jpg
#   inflating: train_v2/f9e6c5752.jpg
#   inflating: train_v2/f9e6dfdb4.jpg
#   inflating: train_v2/f9e71217a.jpg
#   inflating: train_v2/f9e71b088.jpg
#   inflating: train_v2/f9e79a321.jpg
#   inflating: train_v2/f9e859142.jpg
#   inflating: train_v2/f9e86a431.jpg
#   inflating: train_v2/f9e8ac396.jpg
#   inflating: train_v2/f9e8b9e94.jpg
#   inflating: train_v2/f9e95e3da.jpg
#   inflating: train_v2/f9ea6dde9.jpg
#   inflating: train_v2/f9ea7f890.jpg
#   inflating: train_v2/f9ebbdb52.jpg
#   inflating: train_v2/f9ec32242.jpg
#   inflating: train_v2/f9eca7f8e.jpg
#   inflating: train_v2/f9ecd2916.jpg
#   inflating: train_v2/f9ece20fb.jpg
#   inflating: train_v2/f9ed167ac.jpg
#   inflating: train_v2/f9ed987f7.jpg
#   inflating: train_v2/f9ee2aab1.jpg
#   inflating: train_v2/f9ee46ef1.jpg
#   inflating: train_v2/f9ee4c13d.jpg
#   inflating: train_v2/f9ef53a60.jpg
#   inflating: train_v2/f9f0004c4.jpg
#   inflating: train_v2/f9f0a4aea.jpg
#   inflating: train_v2/f9f111fb9.jpg
#   inflating: train_v2/f9f1d1694.jpg
#   inflating: train_v2/f9f30500f.jpg
#   inflating: train_v2/f9f37fbd0.jpg
#   inflating: train_v2/f9f3807d2.jpg
#   inflating: train_v2/f9f3a5e2e.jpg
#   inflating: train_v2/f9f3c25db.jpg
#   inflating: train_v2/f9f41622c.jpg
#   inflating: train_v2/f9f539988.jpg
#   inflating: train_v2/f9f56b801.jpg
#   inflating: train_v2/f9f58dc06.jpg
#   inflating: train_v2/f9f59217d.jpg
#   inflating: train_v2/f9f59b3fb.jpg
#   inflating: train_v2/f9f5fc05a.jpg
#   inflating: train_v2/f9f6c3536.jpg
#   inflating: train_v2/f9f6e0c3e.jpg
#   inflating: train_v2/f9f6f3ce2.jpg
#   inflating: train_v2/f9f6f5005.jpg
#   inflating: train_v2/f9f752f6b.jpg
#   inflating: train_v2/f9f77fb47.jpg
#   inflating: train_v2/f9f96e956.jpg
#   inflating: train_v2/f9f96f7bb.jpg
#   inflating: train_v2/f9fb0ca82.jpg
#   inflating: train_v2/f9fb6b59c.jpg
#   inflating: train_v2/f9fb969b4.jpg
#   inflating: train_v2/f9fc053c9.jpg
#   inflating: train_v2/f9fdf108d.jpg
#   inflating: train_v2/f9fec39ee.jpg
#   inflating: train_v2/f9fec5c77.jpg
#   inflating: train_v2/f9ff4baec.jpg
#   inflating: train_v2/f9ffd7b7a.jpg
#   inflating: train_v2/f9fff8555.jpg
#   inflating: train_v2/fa00e8b93.jpg
#   inflating: train_v2/fa012846b.jpg
#   inflating: train_v2/fa01b4c39.jpg
#   inflating: train_v2/fa01cf63b.jpg
#   inflating: train_v2/fa0200c26.jpg
#   inflating: train_v2/fa029a168.jpg
#   inflating: train_v2/fa02f2102.jpg
#   inflating: train_v2/fa04c1213.jpg
#   inflating: train_v2/fa04f46ca.jpg
#   inflating: train_v2/fa050855d.jpg
#   inflating: train_v2/fa05bbfa6.jpg
#   inflating: train_v2/fa05c0214.jpg
#   inflating: train_v2/fa0663377.jpg
#   inflating: train_v2/fa0679c69.jpg
#   inflating: train_v2/fa068302e.jpg
#   inflating: train_v2/fa06ca979.jpg
#   inflating: train_v2/fa06dd2ff.jpg
#   inflating: train_v2/fa0718c6a.jpg
#   inflating: train_v2/fa0794267.jpg
#   inflating: train_v2/fa07a93ba.jpg
#   inflating: train_v2/fa07dc16c.jpg
#   inflating: train_v2/fa0811fa7.jpg
#   inflating: train_v2/fa0895613.jpg
#   inflating: train_v2/fa08d7720.jpg
#   inflating: train_v2/fa08e1fe3.jpg
#   inflating: train_v2/fa090f3ca.jpg
#   inflating: train_v2/fa0926ae5.jpg
#   inflating: train_v2/fa092f735.jpg
#   inflating: train_v2/fa09406d3.jpg
#   inflating: train_v2/fa09725ec.jpg
#   inflating: train_v2/fa0a62197.jpg
#   inflating: train_v2/fa0a66ac5.jpg
#   inflating: train_v2/fa0a80bc7.jpg
#   inflating: train_v2/fa0abcd5b.jpg
#   inflating: train_v2/fa0adc1e0.jpg
#   inflating: train_v2/fa0adedf4.jpg
#   inflating: train_v2/fa0ae22c9.jpg
#   inflating: train_v2/fa0b6b08e.jpg
#   inflating: train_v2/fa0b8ede3.jpg
#   inflating: train_v2/fa0b9634c.jpg
#   inflating: train_v2/fa0c1901d.jpg
#   inflating: train_v2/fa0c1faba.jpg
#   inflating: train_v2/fa0c47203.jpg
#   inflating: train_v2/fa0c4d02d.jpg
#   inflating: train_v2/fa0cc3c7f.jpg
#   inflating: train_v2/fa0cceedf.jpg
#   inflating: train_v2/fa0ddb084.jpg
#   inflating: train_v2/fa0e5b48d.jpg
#   inflating: train_v2/fa0e75cbd.jpg
#   inflating: train_v2/fa0effd8c.jpg
#   inflating: train_v2/fa0f23034.jpg
#   inflating: train_v2/fa0f34b88.jpg
#   inflating: train_v2/fa0f86121.jpg
#   inflating: train_v2/fa0fb3469.jpg
#   inflating: train_v2/fa10403c9.jpg
#   inflating: train_v2/fa105d7ed.jpg
#   inflating: train_v2/fa1073b6e.jpg
#   inflating: train_v2/fa10860ee.jpg
#   inflating: train_v2/fa115469e.jpg
#   inflating: train_v2/fa1164288.jpg
#   inflating: train_v2/fa1183aab.jpg
#   inflating: train_v2/fa1209156.jpg
#   inflating: train_v2/fa121a51b.jpg
#   inflating: train_v2/fa1267dff.jpg
#   inflating: train_v2/fa12c76af.jpg
#   inflating: train_v2/fa138ae71.jpg
#   inflating: train_v2/fa14f1da9.jpg
#   inflating: train_v2/fa14f8920.jpg
#   inflating: train_v2/fa1506ee2.jpg
#   inflating: train_v2/fa1592711.jpg
#   inflating: train_v2/fa1594af4.jpg
#   inflating: train_v2/fa1595136.jpg
#   inflating: train_v2/fa15ecedd.jpg
#   inflating: train_v2/fa1633dcc.jpg
#   inflating: train_v2/fa16cf7c2.jpg
#   inflating: train_v2/fa16dc7c0.jpg
#   inflating: train_v2/fa16dc996.jpg
#   inflating: train_v2/fa16f3c5b.jpg
#   inflating: train_v2/fa17041f3.jpg
#   inflating: train_v2/fa17a6382.jpg
#   inflating: train_v2/fa17c7680.jpg
#   inflating: train_v2/fa18333e8.jpg
#   inflating: train_v2/fa183413f.jpg
#   inflating: train_v2/fa18811c7.jpg
#   inflating: train_v2/fa18a62f3.jpg
#   inflating: train_v2/fa1900df4.jpg
#   inflating: train_v2/fa192bc29.jpg
#   inflating: train_v2/fa1967760.jpg
#   inflating: train_v2/fa19e5569.jpg
#   inflating: train_v2/fa19fb47a.jpg
#   inflating: train_v2/fa1a365ed.jpg
#   inflating: train_v2/fa1a87411.jpg
#   inflating: train_v2/fa1a895ea.jpg
#   inflating: train_v2/fa1a8b1b8.jpg
#   inflating: train_v2/fa1aa18c2.jpg
#   inflating: train_v2/fa1ae1147.jpg
#   inflating: train_v2/fa1bbeee1.jpg
#   inflating: train_v2/fa1bcedcd.jpg
#   inflating: train_v2/fa1c33ba7.jpg
#   inflating: train_v2/fa1c43cfe.jpg
#   inflating: train_v2/fa1c529cc.jpg
#   inflating: train_v2/fa1c99fd9.jpg
#   inflating: train_v2/fa1cc7677.jpg
#   inflating: train_v2/fa1cc861c.jpg
#   inflating: train_v2/fa1d0cd08.jpg
#   inflating: train_v2/fa1d3aaa3.jpg
#   inflating: train_v2/fa1e01b0f.jpg
#   inflating: train_v2/fa1e3e31d.jpg
#   inflating: train_v2/fa1e49937.jpg
#   inflating: train_v2/fa1ef3b52.jpg
#   inflating: train_v2/fa1ef510c.jpg
#   inflating: train_v2/fa1fd707f.jpg
#   inflating: train_v2/fa20bbfd6.jpg
#   inflating: train_v2/fa2136a29.jpg
#   inflating: train_v2/fa216af84.jpg
#   inflating: train_v2/fa21cc064.jpg
#   inflating: train_v2/fa2288448.jpg
#   inflating: train_v2/fa22e43fa.jpg
#   inflating: train_v2/fa22e7bba.jpg
#   inflating: train_v2/fa238bfc6.jpg
#   inflating: train_v2/fa2420c24.jpg
#   inflating: train_v2/fa245b71c.jpg
#   inflating: train_v2/fa24b66fb.jpg
#   inflating: train_v2/fa25412cc.jpg
#   inflating: train_v2/fa25691aa.jpg
#   inflating: train_v2/fa2597d5e.jpg
#   inflating: train_v2/fa26537e2.jpg
#   inflating: train_v2/fa2664352.jpg
#   inflating: train_v2/fa269af8a.jpg
#   inflating: train_v2/fa272c615.jpg
#   inflating: train_v2/fa275ffdf.jpg
#   inflating: train_v2/fa28793d6.jpg
#   inflating: train_v2/fa289f2c2.jpg
#   inflating: train_v2/fa28b8b00.jpg
#   inflating: train_v2/fa2951b9c.jpg
#   inflating: train_v2/fa2962f24.jpg
#   inflating: train_v2/fa296470b.jpg
#   inflating: train_v2/fa297c479.jpg
#   inflating: train_v2/fa2994b23.jpg
#   inflating: train_v2/fa29c6eb3.jpg
#   inflating: train_v2/fa2a323a9.jpg
#   inflating: train_v2/fa2a85e31.jpg
#   inflating: train_v2/fa2a93fe6.jpg
#   inflating: train_v2/fa2b1b5d1.jpg
#   inflating: train_v2/fa2b41c31.jpg
#   inflating: train_v2/fa2b65324.jpg
#   inflating: train_v2/fa2ba602b.jpg
#   inflating: train_v2/fa2c45013.jpg
#   inflating: train_v2/fa2d39c28.jpg
#   inflating: train_v2/fa2d42a31.jpg
#   inflating: train_v2/fa2d5f962.jpg
#   inflating: train_v2/fa2db44f0.jpg
#   inflating: train_v2/fa2e4748d.jpg
#   inflating: train_v2/fa2e94e85.jpg
#   inflating: train_v2/fa2ef1fe2.jpg
#   inflating: train_v2/fa2f89556.jpg
#   inflating: train_v2/fa2fba272.jpg
#   inflating: train_v2/fa2fe974d.jpg
#   inflating: train_v2/fa3053b52.jpg
#   inflating: train_v2/fa30669d4.jpg
#   inflating: train_v2/fa309ab52.jpg
#   inflating: train_v2/fa30bfdb5.jpg
#   inflating: train_v2/fa31db6c5.jpg
#   inflating: train_v2/fa32211b4.jpg
#   inflating: train_v2/fa3380f1e.jpg
#   inflating: train_v2/fa3429485.jpg
#   inflating: train_v2/fa3456bbc.jpg
#   inflating: train_v2/fa35c56a4.jpg
#   inflating: train_v2/fa35c8662.jpg
#   inflating: train_v2/fa362fdb1.jpg
#   inflating: train_v2/fa36defc8.jpg
#   inflating: train_v2/fa36e6d71.jpg
#   inflating: train_v2/fa370d3e1.jpg
#   inflating: train_v2/fa373bd58.jpg
#   inflating: train_v2/fa37c3b21.jpg
#   inflating: train_v2/fa37c48a5.jpg
#   inflating: train_v2/fa385bac6.jpg
#   inflating: train_v2/fa3919015.jpg
#   inflating: train_v2/fa397eaf8.jpg
#   inflating: train_v2/fa3988826.jpg
#   inflating: train_v2/fa39b75aa.jpg
#   inflating: train_v2/fa3a100c7.jpg
#   inflating: train_v2/fa3a11eae.jpg
#   inflating: train_v2/fa3a359fa.jpg
#   inflating: train_v2/fa3a7eb5f.jpg
#   inflating: train_v2/fa3aa7011.jpg
#   inflating: train_v2/fa3ab8a0e.jpg
#   inflating: train_v2/fa3b7d9e8.jpg
#   inflating: train_v2/fa3c61e0c.jpg
#   inflating: train_v2/fa3ca8a2a.jpg
#   inflating: train_v2/fa3df62cf.jpg
#   inflating: train_v2/fa3e19456.jpg
#   inflating: train_v2/fa3eaf4ea.jpg
#   inflating: train_v2/fa3eba6b3.jpg
#   inflating: train_v2/fa3fb3484.jpg
#   inflating: train_v2/fa40d72fa.jpg
#   inflating: train_v2/fa40d7d72.jpg
#   inflating: train_v2/fa4121496.jpg
#   inflating: train_v2/fa416f0d8.jpg
#   inflating: train_v2/fa41a2fef.jpg
#   inflating: train_v2/fa41c0a6a.jpg
#   inflating: train_v2/fa42059a5.jpg
#   inflating: train_v2/fa421d893.jpg
#   inflating: train_v2/fa425d5ea.jpg
#   inflating: train_v2/fa4288cfd.jpg
#   inflating: train_v2/fa42e513e.jpg
#   inflating: train_v2/fa43a03c0.jpg
#   inflating: train_v2/fa446d7bd.jpg
#   inflating: train_v2/fa4483b95.jpg
#   inflating: train_v2/fa44a1eea.jpg
#   inflating: train_v2/fa44b23ff.jpg
#   inflating: train_v2/fa45a5c4c.jpg
#   inflating: train_v2/fa45b1ba3.jpg
#   inflating: train_v2/fa465fbdb.jpg
#   inflating: train_v2/fa469215b.jpg
#   inflating: train_v2/fa4744752.jpg
#   inflating: train_v2/fa476058d.jpg
#   inflating: train_v2/fa47a8c4d.jpg
#   inflating: train_v2/fa48846f8.jpg
#   inflating: train_v2/fa48bfb06.jpg
#   inflating: train_v2/fa4925d6d.jpg
#   inflating: train_v2/fa4a030f2.jpg
#   inflating: train_v2/fa4a5229d.jpg
#   inflating: train_v2/fa4a90785.jpg
#   inflating: train_v2/fa4ab2025.jpg
#   inflating: train_v2/fa4afcd12.jpg
#   inflating: train_v2/fa4b4f7d1.jpg
#   inflating: train_v2/fa4b87e64.jpg
#   inflating: train_v2/fa4b9ea02.jpg
#   inflating: train_v2/fa4c1eabb.jpg
#   inflating: train_v2/fa4c57815.jpg
#   inflating: train_v2/fa4cce372.jpg
#   inflating: train_v2/fa4d115e8.jpg
#   inflating: train_v2/fa4d6efb5.jpg
#   inflating: train_v2/fa4d8404a.jpg
#   inflating: train_v2/fa4d92655.jpg
#   inflating: train_v2/fa4d95ad8.jpg
#   inflating: train_v2/fa4ddd5f4.jpg
#   inflating: train_v2/fa4e8e905.jpg
#   inflating: train_v2/fa4ed776d.jpg
#   inflating: train_v2/fa4edd592.jpg
#   inflating: train_v2/fa4f04a1a.jpg
#   inflating: train_v2/fa4f1921d.jpg
#   inflating: train_v2/fa4f1b8e0.jpg
#   inflating: train_v2/fa4f1d514.jpg
#   inflating: train_v2/fa4f66f50.jpg
#   inflating: train_v2/fa4feb886.jpg
#   inflating: train_v2/fa500c46e.jpg
#   inflating: train_v2/fa502217b.jpg
#   inflating: train_v2/fa50867b1.jpg
#   inflating: train_v2/fa5087729.jpg
#   inflating: train_v2/fa5088574.jpg
#   inflating: train_v2/fa50e9c33.jpg
#   inflating: train_v2/fa51141cb.jpg
#   inflating: train_v2/fa516551c.jpg
#   inflating: train_v2/fa519d70e.jpg
#   inflating: train_v2/fa5236916.jpg
#   inflating: train_v2/fa527bede.jpg
#   inflating: train_v2/fa5289ac2.jpg
#   inflating: train_v2/fa52b1f97.jpg
#   inflating: train_v2/fa52dcc92.jpg
#   inflating: train_v2/fa52dfc77.jpg
#   inflating: train_v2/fa52ef63a.jpg
#   inflating: train_v2/fa532b835.jpg
#   inflating: train_v2/fa53811e2.jpg
#   inflating: train_v2/fa5392c8b.jpg
#   inflating: train_v2/fa5454f81.jpg
#   inflating: train_v2/fa54fa20a.jpg
#   inflating: train_v2/fa550cbc3.jpg
#   inflating: train_v2/fa558c02f.jpg
#   inflating: train_v2/fa55bb0c3.jpg
#   inflating: train_v2/fa5600634.jpg
#   inflating: train_v2/fa56143d8.jpg
#   inflating: train_v2/fa5639d5e.jpg
#   inflating: train_v2/fa566b406.jpg
#   inflating: train_v2/fa56bcd53.jpg
#   inflating: train_v2/fa5815009.jpg
#   inflating: train_v2/fa584cbaa.jpg
#   inflating: train_v2/fa5a4422c.jpg
#   inflating: train_v2/fa5a8608c.jpg
#   inflating: train_v2/fa5af0c65.jpg
#   inflating: train_v2/fa5b5284e.jpg
#   inflating: train_v2/fa5bd647a.jpg
#   inflating: train_v2/fa5be25de.jpg
#   inflating: train_v2/fa5c0c8b7.jpg
#   inflating: train_v2/fa5c15fe6.jpg
#   inflating: train_v2/fa5cf7466.jpg
#   inflating: train_v2/fa5d005a1.jpg
#   inflating: train_v2/fa5d25aea.jpg
#   inflating: train_v2/fa5d90ef2.jpg
#   inflating: train_v2/fa5dadaed.jpg
#   inflating: train_v2/fa5f448de.jpg
#   inflating: train_v2/fa5facf22.jpg
#   inflating: train_v2/fa5ffe49f.jpg
#   inflating: train_v2/fa60b9824.jpg
#   inflating: train_v2/fa60f8b5a.jpg
#   inflating: train_v2/fa612c590.jpg
#   inflating: train_v2/fa613751e.jpg
#   inflating: train_v2/fa6210d11.jpg
#   inflating: train_v2/fa6258010.jpg
#   inflating: train_v2/fa62d2625.jpg
#   inflating: train_v2/fa62e33a4.jpg
#   inflating: train_v2/fa62f73e3.jpg
#   inflating: train_v2/fa63137f1.jpg
#   inflating: train_v2/fa63387ab.jpg
#   inflating: train_v2/fa6356231.jpg
#   inflating: train_v2/fa636ff22.jpg
#   inflating: train_v2/fa638eecd.jpg
#   inflating: train_v2/fa63af1e7.jpg
#   inflating: train_v2/fa63e1484.jpg
#   inflating: train_v2/fa640d5ee.jpg
#   inflating: train_v2/fa640dcb8.jpg
#   inflating: train_v2/fa647625c.jpg
#   inflating: train_v2/fa651c9a7.jpg
#   inflating: train_v2/fa65e64b9.jpg
#   inflating: train_v2/fa66b55ec.jpg
#   inflating: train_v2/fa66df0e9.jpg
#   inflating: train_v2/fa6771ec1.jpg
#   inflating: train_v2/fa67d8fa2.jpg
#   inflating: train_v2/fa6941279.jpg
#   inflating: train_v2/fa697fd49.jpg
#   inflating: train_v2/fa69e05dc.jpg
#   inflating: train_v2/fa6a0c322.jpg
#   inflating: train_v2/fa6a42b4a.jpg
#   inflating: train_v2/fa6a53e3a.jpg
#   inflating: train_v2/fa6a9003a.jpg
#   inflating: train_v2/fa6b16092.jpg
#   inflating: train_v2/fa6be2001.jpg
#   inflating: train_v2/fa6c0270c.jpg
#   inflating: train_v2/fa6c3b712.jpg
#   inflating: train_v2/fa6c47f4c.jpg
#   inflating: train_v2/fa6d2238f.jpg
#   inflating: train_v2/fa6d85fc2.jpg
#   inflating: train_v2/fa6d86256.jpg
#   inflating: train_v2/fa6e03182.jpg
#   inflating: train_v2/fa6eab94c.jpg
#   inflating: train_v2/fa6eda3a8.jpg
#   inflating: train_v2/fa6edd7a0.jpg
#   inflating: train_v2/fa6ef84bb.jpg
#   inflating: train_v2/fa6f0075d.jpg
#   inflating: train_v2/fa6f4efaf.jpg
#   inflating: train_v2/fa6fc3eb8.jpg
#   inflating: train_v2/fa7035fd7.jpg
#   inflating: train_v2/fa70b8628.jpg
#   inflating: train_v2/fa70bbdf8.jpg
#   inflating: train_v2/fa70e67bd.jpg
#   inflating: train_v2/fa71c5596.jpg
#   inflating: train_v2/fa7289c94.jpg
#   inflating: train_v2/fa72ecd12.jpg
#   inflating: train_v2/fa734919f.jpg
#   inflating: train_v2/fa737e089.jpg
#   inflating: train_v2/fa7471016.jpg
#   inflating: train_v2/fa747b691.jpg
#   inflating: train_v2/fa754b70d.jpg
#   inflating: train_v2/fa755ccbd.jpg
#   inflating: train_v2/fa75a51a8.jpg
#   inflating: train_v2/fa75f1c5e.jpg
#   inflating: train_v2/fa7683cdd.jpg
#   inflating: train_v2/fa7720ac7.jpg
#   inflating: train_v2/fa7780381.jpg
#   inflating: train_v2/fa7823800.jpg
#   inflating: train_v2/fa78668a1.jpg
#   inflating: train_v2/fa787568f.jpg
#   inflating: train_v2/fa788a0cd.jpg
#   inflating: train_v2/fa78a2e7b.jpg
#   inflating: train_v2/fa799e693.jpg
#   inflating: train_v2/fa7a33a8f.jpg
#   inflating: train_v2/fa7a5f1e4.jpg
#   inflating: train_v2/fa7ae82f8.jpg
#   inflating: train_v2/fa7c7616d.jpg
#   inflating: train_v2/fa7cba10b.jpg
#   inflating: train_v2/fa7d0837c.jpg
#   inflating: train_v2/fa7d359fa.jpg
#   inflating: train_v2/fa7d74983.jpg
#   inflating: train_v2/fa7dee673.jpg
#   inflating: train_v2/fa7e55f60.jpg
#   inflating: train_v2/fa7eb49b9.jpg
#   inflating: train_v2/fa7f06a3a.jpg
#   inflating: train_v2/fa7f1de64.jpg
#   inflating: train_v2/fa7f334b0.jpg
#   inflating: train_v2/fa7f3fda3.jpg
#   inflating: train_v2/fa80202b2.jpg
#   inflating: train_v2/fa804b842.jpg
#   inflating: train_v2/fa805e667.jpg
#   inflating: train_v2/fa8060e4b.jpg
#   inflating: train_v2/fa81cb2f2.jpg
#   inflating: train_v2/fa81fe0d7.jpg
#   inflating: train_v2/fa8227ad1.jpg
#   inflating: train_v2/fa8273e05.jpg
#   inflating: train_v2/fa82c7831.jpg
#   inflating: train_v2/fa82d3b64.jpg
#   inflating: train_v2/fa83106e4.jpg
#   inflating: train_v2/fa83c57c3.jpg
#   inflating: train_v2/fa83d3250.jpg
#   inflating: train_v2/fa83f7356.jpg
#   inflating: train_v2/fa840f7e8.jpg
#   inflating: train_v2/fa84223d5.jpg
#   inflating: train_v2/fa8432f79.jpg
#   inflating: train_v2/fa8549849.jpg
#   inflating: train_v2/fa855348d.jpg
#   inflating: train_v2/fa858a2b2.jpg
#   inflating: train_v2/fa85e881f.jpg
#   inflating: train_v2/fa8614506.jpg
#   inflating: train_v2/fa86a34f1.jpg
#   inflating: train_v2/fa86b0523.jpg
#   inflating: train_v2/fa8783e95.jpg
#   inflating: train_v2/fa879c13b.jpg
#   inflating: train_v2/fa87e7113.jpg
#   inflating: train_v2/fa881001a.jpg
#   inflating: train_v2/fa8822e08.jpg
#   inflating: train_v2/fa88367bb.jpg
#   inflating: train_v2/fa884d559.jpg
#   inflating: train_v2/fa884fe93.jpg
#   inflating: train_v2/fa885b95b.jpg
#   inflating: train_v2/fa8871f1c.jpg
#   inflating: train_v2/fa88eb332.jpg
#   inflating: train_v2/fa899b515.jpg
#   inflating: train_v2/fa8b01881.jpg
#   inflating: train_v2/fa8b0bb8f.jpg
#   inflating: train_v2/fa8b6e4f2.jpg
#   inflating: train_v2/fa8bacd24.jpg
#   inflating: train_v2/fa8c382db.jpg
#   inflating: train_v2/fa8c4b66b.jpg
#   inflating: train_v2/fa8d32ee9.jpg
#   inflating: train_v2/fa8d65a3d.jpg
#   inflating: train_v2/fa8e18e5d.jpg
#   inflating: train_v2/fa8eb6aba.jpg
#   inflating: train_v2/fa8efce6b.jpg
#   inflating: train_v2/fa8f09970.jpg
#   inflating: train_v2/fa8f715ab.jpg
#   inflating: train_v2/fa8fe554c.jpg
#   inflating: train_v2/fa9022067.jpg
#   inflating: train_v2/fa90eeb79.jpg
#   inflating: train_v2/fa90f1adb.jpg
#   inflating: train_v2/fa90f25a1.jpg
#   inflating: train_v2/fa9109b26.jpg
#   inflating: train_v2/fa91657f7.jpg
#   inflating: train_v2/fa9169219.jpg
#   inflating: train_v2/fa918db33.jpg
#   inflating: train_v2/fa920f9c5.jpg
#   inflating: train_v2/fa9227f57.jpg
#   inflating: train_v2/fa92de902.jpg
#   inflating: train_v2/fa92e060b.jpg
#   inflating: train_v2/fa933f4b6.jpg
#   inflating: train_v2/fa936b5e1.jpg
#   inflating: train_v2/fa93a562a.jpg
#   inflating: train_v2/fa93c1f32.jpg
#   inflating: train_v2/fa9420df0.jpg
#   inflating: train_v2/fa947efb8.jpg
#   inflating: train_v2/fa94c02aa.jpg
#   inflating: train_v2/fa94e3719.jpg
#   inflating: train_v2/fa95a96f7.jpg
#   inflating: train_v2/fa961fb3d.jpg
#   inflating: train_v2/fa974533f.jpg
#   inflating: train_v2/fa974d0d1.jpg
#   inflating: train_v2/fa9776df8.jpg
#   inflating: train_v2/fa978da80.jpg
#   inflating: train_v2/fa98163a6.jpg
#   inflating: train_v2/fa981a350.jpg
#   inflating: train_v2/fa98be694.jpg
#   inflating: train_v2/fa98e26b3.jpg
#   inflating: train_v2/fa992b736.jpg
#   inflating: train_v2/fa992ed1a.jpg
#   inflating: train_v2/fa99d968f.jpg
#   inflating: train_v2/fa9a33889.jpg
#   inflating: train_v2/fa9a8d10c.jpg
#   inflating: train_v2/fa9a8fb87.jpg
#   inflating: train_v2/fa9b4bca0.jpg
#   inflating: train_v2/fa9c6d728.jpg
#   inflating: train_v2/fa9c86d76.jpg
#   inflating: train_v2/fa9d579c1.jpg
#   inflating: train_v2/fa9ed5345.jpg
#   inflating: train_v2/fa9f48207.jpg
#   inflating: train_v2/fa9f6e863.jpg
#   inflating: train_v2/fa9f96164.jpg
#   inflating: train_v2/faa04a9e3.jpg
#   inflating: train_v2/faa0f7b75.jpg
#   inflating: train_v2/faa148a78.jpg
#   inflating: train_v2/faa203454.jpg
#   inflating: train_v2/faa225f0c.jpg
#   inflating: train_v2/faa22ace6.jpg
#   inflating: train_v2/faa25e4cf.jpg
#   inflating: train_v2/faa28bde3.jpg
#   inflating: train_v2/faa2a7e49.jpg
#   inflating: train_v2/faa33ce4d.jpg
#   inflating: train_v2/faa37de39.jpg
#   inflating: train_v2/faa37f7f3.jpg
#   inflating: train_v2/faa3a5e6e.jpg
#   inflating: train_v2/faa40285a.jpg
#   inflating: train_v2/faa4240c1.jpg
#   inflating: train_v2/faa4a3f0c.jpg
#   inflating: train_v2/faa614855.jpg
#   inflating: train_v2/faa6d4fb0.jpg
#   inflating: train_v2/faa739c1f.jpg
#   inflating: train_v2/faa7acfd8.jpg
#   inflating: train_v2/faa7c7e45.jpg
#   inflating: train_v2/faa822d75.jpg
#   inflating: train_v2/faa876267.jpg
#   inflating: train_v2/faa8c7f65.jpg
#   inflating: train_v2/faa8eaaa4.jpg
#   inflating: train_v2/faa97745d.jpg
#   inflating: train_v2/faa98db0f.jpg
#   inflating: train_v2/faa9ad36a.jpg
#   inflating: train_v2/faaa01699.jpg
#   inflating: train_v2/faaae89a8.jpg
#   inflating: train_v2/faaaea4da.jpg
#   inflating: train_v2/faaaedf15.jpg
#   inflating: train_v2/faab69112.jpg
#   inflating: train_v2/faab6c3a5.jpg
#   inflating: train_v2/faab99035.jpg
#   inflating: train_v2/faabc6f5d.jpg
#   inflating: train_v2/faac75c4a.jpg
#   inflating: train_v2/faacd95a6.jpg
#   inflating: train_v2/faad01dd3.jpg
#   inflating: train_v2/faad38ae5.jpg
#   inflating: train_v2/faad630e8.jpg
#   inflating: train_v2/faad73376.jpg
#   inflating: train_v2/faae36044.jpg
#   inflating: train_v2/faae70528.jpg
#   inflating: train_v2/faae73fb9.jpg
#   inflating: train_v2/faae7aabf.jpg
#   inflating: train_v2/faaf0debf.jpg
#   inflating: train_v2/faaf48322.jpg
#   inflating: train_v2/faafe084a.jpg
#   inflating: train_v2/fab0a5a37.jpg
#   inflating: train_v2/fab0dc2cc.jpg
#   inflating: train_v2/fab14cda3.jpg
#   inflating: train_v2/fab173b12.jpg
#   inflating: train_v2/fab1e0072.jpg
#   inflating: train_v2/fab1f9718.jpg
#   inflating: train_v2/fab214049.jpg
#   inflating: train_v2/fab24dbeb.jpg
#   inflating: train_v2/fab2854f4.jpg
#   inflating: train_v2/fab2b24d3.jpg
#   inflating: train_v2/fab30d5ad.jpg
#   inflating: train_v2/fab38a881.jpg
#   inflating: train_v2/fab3dc88b.jpg
#   inflating: train_v2/fab493297.jpg
#   inflating: train_v2/fab4dfe8b.jpg
#   inflating: train_v2/fab4eefe6.jpg
#   inflating: train_v2/fab576771.jpg
#   inflating: train_v2/fab5fa589.jpg
#   inflating: train_v2/fab6c921d.jpg
#   inflating: train_v2/fab75466e.jpg
#   inflating: train_v2/fab762b1d.jpg
#   inflating: train_v2/fab804fe7.jpg
#   inflating: train_v2/fab80a03f.jpg
#   inflating: train_v2/fab829323.jpg
#   inflating: train_v2/fab852c71.jpg
#   inflating: train_v2/fab90d8dd.jpg
#   inflating: train_v2/fab933d17.jpg
#   inflating: train_v2/fab93890b.jpg
#   inflating: train_v2/fab9fa6cb.jpg
#   inflating: train_v2/fabaf9859.jpg
#   inflating: train_v2/fabb06ae2.jpg
#   inflating: train_v2/fabb7d357.jpg
#   inflating: train_v2/fabb8f509.jpg
#   inflating: train_v2/fabc045f5.jpg
#   inflating: train_v2/fabc7e15a.jpg
#   inflating: train_v2/fabcbfd9e.jpg
#   inflating: train_v2/fabe365e1.jpg
#   inflating: train_v2/fabe71837.jpg
#   inflating: train_v2/fabed03d9.jpg
#   inflating: train_v2/fabf12d21.jpg
#   inflating: train_v2/fabfc0c6e.jpg
#   inflating: train_v2/fabffb27a.jpg
#   inflating: train_v2/fac024c23.jpg
#   inflating: train_v2/fac161c5e.jpg
#   inflating: train_v2/fac1c69ce.jpg
#   inflating: train_v2/fac1d7c0b.jpg
#   inflating: train_v2/fac263d5d.jpg
#   inflating: train_v2/fac26a8c4.jpg
#   inflating: train_v2/fac350862.jpg
#   inflating: train_v2/fac362381.jpg
#   inflating: train_v2/fac372c6c.jpg
#   inflating: train_v2/fac48128c.jpg
#   inflating: train_v2/fac490e45.jpg
#   inflating: train_v2/fac4a6523.jpg
#   inflating: train_v2/fac521308.jpg
#   inflating: train_v2/fac54254a.jpg
#   inflating: train_v2/fac544ad6.jpg
#   inflating: train_v2/fac560b2e.jpg
#   inflating: train_v2/fac5d4d35.jpg
#   inflating: train_v2/fac5f015c.jpg
#   inflating: train_v2/fac60820c.jpg
#   inflating: train_v2/fac642c98.jpg
#   inflating: train_v2/fac6a92bf.jpg
#   inflating: train_v2/fac732b9a.jpg
#   inflating: train_v2/fac774789.jpg
#   inflating: train_v2/fac7a529e.jpg
#   inflating: train_v2/fac7a90c9.jpg
#   inflating: train_v2/fac7de3e7.jpg
#   inflating: train_v2/fac7e29b3.jpg
#   inflating: train_v2/fac888dd0.jpg
#   inflating: train_v2/fac917a5a.jpg
#   inflating: train_v2/fac91f887.jpg
#   inflating: train_v2/fac9e4671.jpg
#   inflating: train_v2/faca323ed.jpg
#   inflating: train_v2/faca61548.jpg
#   inflating: train_v2/faca72006.jpg
#   inflating: train_v2/facb2b0f1.jpg
#   inflating: train_v2/facb8005e.jpg
#   inflating: train_v2/facbbec2a.jpg
#   inflating: train_v2/facbcab66.jpg
#   inflating: train_v2/faccab4a4.jpg
#   inflating: train_v2/facdac9ec.jpg
#   inflating: train_v2/facdadf14.jpg
#   inflating: train_v2/facdebd83.jpg
#   inflating: train_v2/facdf829f.jpg
#   inflating: train_v2/face079bc.jpg
#   inflating: train_v2/face29618.jpg
#   inflating: train_v2/face4646f.jpg
#   inflating: train_v2/face58f3d.jpg
#   inflating: train_v2/facf1ced4.jpg
#   inflating: train_v2/facf24946.jpg
#   inflating: train_v2/facf4bea1.jpg
#   inflating: train_v2/facf5a92c.jpg
#   inflating: train_v2/facfbfd88.jpg
#   inflating: train_v2/fad030e9d.jpg
#   inflating: train_v2/fad221680.jpg
#   inflating: train_v2/fad27369f.jpg
#   inflating: train_v2/fad2a1dee.jpg
#   inflating: train_v2/fad33e2ee.jpg
#   inflating: train_v2/fad373f20.jpg
#   inflating: train_v2/fad3d454d.jpg
#   inflating: train_v2/fad3edfca.jpg
#   inflating: train_v2/fad41e682.jpg
#   inflating: train_v2/fad42cfb2.jpg
#   inflating: train_v2/fad43cf41.jpg
#   inflating: train_v2/fad442819.jpg
#   inflating: train_v2/fad44790d.jpg
#   inflating: train_v2/fad486d55.jpg
#   inflating: train_v2/fad4a6c46.jpg
#   inflating: train_v2/fad523ca2.jpg
#   inflating: train_v2/fad5639d2.jpg
#   inflating: train_v2/fad5b6d58.jpg
#   inflating: train_v2/fad674252.jpg
#   inflating: train_v2/fad688ee7.jpg
#   inflating: train_v2/fad68a3cd.jpg
#   inflating: train_v2/fad69cb70.jpg
#   inflating: train_v2/fad6ba4f2.jpg
#   inflating: train_v2/fad7c78af.jpg
#   inflating: train_v2/fad86a0b9.jpg
#   inflating: train_v2/fad883930.jpg
#   inflating: train_v2/fad8caed8.jpg
#   inflating: train_v2/fad8d8b63.jpg
#   inflating: train_v2/fad9329c3.jpg
#   inflating: train_v2/fad9c1f74.jpg
#   inflating: train_v2/fad9cfb16.jpg
#   inflating: train_v2/fada00e56.jpg
#   inflating: train_v2/fada39cd3.jpg
#   inflating: train_v2/fada6d040.jpg
#   inflating: train_v2/fadad1855.jpg
#   inflating: train_v2/fadb0eb37.jpg
#   inflating: train_v2/fadb4a74d.jpg
#   inflating: train_v2/fadc2afb1.jpg
#   inflating: train_v2/fadc3eb1b.jpg
#   inflating: train_v2/fadc9d577.jpg
#   inflating: train_v2/fadcac145.jpg
#   inflating: train_v2/fadcbb181.jpg
#   inflating: train_v2/fadd327d9.jpg
#   inflating: train_v2/fadd9dfea.jpg
#   inflating: train_v2/fadde2a5e.jpg
#   inflating: train_v2/fade5b67c.jpg
#   inflating: train_v2/fade6c947.jpg
#   inflating: train_v2/fadea0584.jpg
#   inflating: train_v2/fadec8523.jpg
#   inflating: train_v2/fadeda837.jpg
#   inflating: train_v2/fadf0862b.jpg
#   inflating: train_v2/fadf39647.jpg
#   inflating: train_v2/fadf68253.jpg
#   inflating: train_v2/fadfa1586.jpg
#   inflating: train_v2/fae086e80.jpg
#   inflating: train_v2/fae107214.jpg
#   inflating: train_v2/fae15ea69.jpg
#   inflating: train_v2/fae2500c2.jpg
#   inflating: train_v2/fae27a8f6.jpg
#   inflating: train_v2/fae2d0c82.jpg
#   inflating: train_v2/fae2ffac5.jpg
#   inflating: train_v2/fae310463.jpg
#   inflating: train_v2/fae31c077.jpg
#   inflating: train_v2/fae33b7e4.jpg
#   inflating: train_v2/fae379ac6.jpg
#   inflating: train_v2/fae3de17f.jpg
#   inflating: train_v2/fae406897.jpg
#   inflating: train_v2/fae67e20e.jpg
#   inflating: train_v2/fae752f07.jpg
#   inflating: train_v2/fae76a75e.jpg
#   inflating: train_v2/fae825ee3.jpg
#   inflating: train_v2/fae876f25.jpg
#   inflating: train_v2/fae935591.jpg
#   inflating: train_v2/fae939272.jpg
#   inflating: train_v2/fae978d96.jpg
#   inflating: train_v2/fae99eaba.jpg
#   inflating: train_v2/fae9eeb79.jpg
#   inflating: train_v2/faea5f3b9.jpg
#   inflating: train_v2/faea69673.jpg
#   inflating: train_v2/faead3394.jpg
#   inflating: train_v2/faeaf668b.jpg
#   inflating: train_v2/faeb227d8.jpg
#   inflating: train_v2/faeb3e071.jpg
#   inflating: train_v2/faeb959ac.jpg
#   inflating: train_v2/faeb9de9f.jpg
#   inflating: train_v2/faebdd76e.jpg
#   inflating: train_v2/faebebb67.jpg
#   inflating: train_v2/faec520a9.jpg
#   inflating: train_v2/faec72d41.jpg
#   inflating: train_v2/faecc0fb7.jpg
#   inflating: train_v2/faecccf7a.jpg
#   inflating: train_v2/faed45b98.jpg
#   inflating: train_v2/faee4c38e.jpg
#   inflating: train_v2/faee575cd.jpg
#   inflating: train_v2/faf07c310.jpg
#   inflating: train_v2/faf0bdb66.jpg
#   inflating: train_v2/faf0fee16.jpg
#   inflating: train_v2/faf131bee.jpg
#   inflating: train_v2/faf19bef2.jpg
#   inflating: train_v2/faf1de5c0.jpg
#   inflating: train_v2/faf23e5dc.jpg
#   inflating: train_v2/faf2dd732.jpg
#   inflating: train_v2/faf2e68c9.jpg
#   inflating: train_v2/faf312795.jpg
#   inflating: train_v2/faf3a71c7.jpg
#   inflating: train_v2/faf4d39ca.jpg
#   inflating: train_v2/faf53a8e1.jpg
#   inflating: train_v2/faf586cfc.jpg
#   inflating: train_v2/faf59341d.jpg
#   inflating: train_v2/faf5e7da9.jpg
#   inflating: train_v2/faf5ea5e1.jpg
#   inflating: train_v2/faf6755cd.jpg
#   inflating: train_v2/faf7107fb.jpg
#   inflating: train_v2/faf780b1d.jpg
#   inflating: train_v2/faf7a2ccd.jpg
#   inflating: train_v2/faf7ee30c.jpg
#   inflating: train_v2/faf825619.jpg
#   inflating: train_v2/faf9655b9.jpg
#   inflating: train_v2/faf982187.jpg
#   inflating: train_v2/faf9fe257.jpg
#   inflating: train_v2/fafa6a883.jpg
#   inflating: train_v2/fafa7965e.jpg
#   inflating: train_v2/fafbff666.jpg
#   inflating: train_v2/fafcd5c70.jpg
#   inflating: train_v2/fafd00ed7.jpg
#   inflating: train_v2/fafd2c779.jpg
#   inflating: train_v2/fafd721ee.jpg
#   inflating: train_v2/fafd90813.jpg
#   inflating: train_v2/fafda357b.jpg
#   inflating: train_v2/fafe05f44.jpg
#   inflating: train_v2/fafe178e6.jpg
#   inflating: train_v2/fafe400fc.jpg
#   inflating: train_v2/fafeaa123.jpg
#   inflating: train_v2/fafec687e.jpg
#   inflating: train_v2/faff144dc.jpg
#   inflating: train_v2/faff17102.jpg
#   inflating: train_v2/faff3e436.jpg
#   inflating: train_v2/faff88bbe.jpg
#   inflating: train_v2/fb005106c.jpg
#   inflating: train_v2/fb00e1f35.jpg
#   inflating: train_v2/fb0116b6b.jpg
#   inflating: train_v2/fb01348ca.jpg
#   inflating: train_v2/fb013a5d9.jpg
#   inflating: train_v2/fb02a562d.jpg
#   inflating: train_v2/fb03171e5.jpg
#   inflating: train_v2/fb03b724e.jpg
#   inflating: train_v2/fb04a5f33.jpg
#   inflating: train_v2/fb04bf7bd.jpg
#   inflating: train_v2/fb04e8d74.jpg
#   inflating: train_v2/fb057a5da.jpg
#   inflating: train_v2/fb05b7950.jpg
#   inflating: train_v2/fb05c4262.jpg
#   inflating: train_v2/fb05c6290.jpg
#   inflating: train_v2/fb05d211b.jpg
#   inflating: train_v2/fb05dd5a8.jpg
#   inflating: train_v2/fb05ea231.jpg
#   inflating: train_v2/fb075a5d5.jpg
#   inflating: train_v2/fb075db8b.jpg
#   inflating: train_v2/fb076472d.jpg
#   inflating: train_v2/fb078edac.jpg
#   inflating: train_v2/fb07a6017.jpg
#   inflating: train_v2/fb08253b2.jpg
#   inflating: train_v2/fb085388a.jpg
#   inflating: train_v2/fb0869e1a.jpg
#   inflating: train_v2/fb08c0cb8.jpg
#   inflating: train_v2/fb08c38bf.jpg
#   inflating: train_v2/fb08eb24a.jpg
#   inflating: train_v2/fb090e305.jpg
#   inflating: train_v2/fb0926885.jpg
#   inflating: train_v2/fb093782c.jpg
#   inflating: train_v2/fb094e95c.jpg
#   inflating: train_v2/fb098d758.jpg
#   inflating: train_v2/fb0a205d5.jpg
#   inflating: train_v2/fb0a8a189.jpg
#   inflating: train_v2/fb0aafcab.jpg
#   inflating: train_v2/fb0b22184.jpg
#   inflating: train_v2/fb0b48df5.jpg
#   inflating: train_v2/fb0b8cbc2.jpg
#   inflating: train_v2/fb0b96200.jpg
#   inflating: train_v2/fb0b9c6c0.jpg
#   inflating: train_v2/fb0ba672a.jpg
#   inflating: train_v2/fb0c64da4.jpg
#   inflating: train_v2/fb0c64dda.jpg
#   inflating: train_v2/fb0d2c170.jpg
#   inflating: train_v2/fb0d791e8.jpg
#   inflating: train_v2/fb0e7c0f1.jpg
#   inflating: train_v2/fb0e80085.jpg
#   inflating: train_v2/fb0f9ad58.jpg
#   inflating: train_v2/fb0fdbb7c.jpg
#   inflating: train_v2/fb0ff67f3.jpg
#   inflating: train_v2/fb1008dd2.jpg
#   inflating: train_v2/fb1071b0f.jpg
#   inflating: train_v2/fb10b23c6.jpg
#   inflating: train_v2/fb10c0923.jpg
#   inflating: train_v2/fb117af19.jpg
#   inflating: train_v2/fb11cdc7d.jpg
#   inflating: train_v2/fb11d7477.jpg
#   inflating: train_v2/fb12432cb.jpg
#   inflating: train_v2/fb127cea9.jpg
#   inflating: train_v2/fb12fe140.jpg
#   inflating: train_v2/fb1327016.jpg
#   inflating: train_v2/fb1360f92.jpg
#   inflating: train_v2/fb13d5ddb.jpg
#   inflating: train_v2/fb13fde64.jpg
#   inflating: train_v2/fb140d3c5.jpg
#   inflating: train_v2/fb14845c3.jpg
#   inflating: train_v2/fb14f7c01.jpg
#   inflating: train_v2/fb1598b84.jpg
#   inflating: train_v2/fb15cb2b0.jpg
#   inflating: train_v2/fb1619fbb.jpg
#   inflating: train_v2/fb16862a2.jpg
#   inflating: train_v2/fb16ccaef.jpg
#   inflating: train_v2/fb17b0ac8.jpg
#   inflating: train_v2/fb1837511.jpg
#   inflating: train_v2/fb192bb53.jpg
#   inflating: train_v2/fb193aa00.jpg
#   inflating: train_v2/fb19c2c85.jpg
#   inflating: train_v2/fb19ca3fd.jpg
#   inflating: train_v2/fb19f3970.jpg
#   inflating: train_v2/fb1a247a2.jpg
#   inflating: train_v2/fb1ac920b.jpg
#   inflating: train_v2/fb1b3b06a.jpg
#   inflating: train_v2/fb1b9ab1d.jpg
#   inflating: train_v2/fb1bf87a1.jpg
#   inflating: train_v2/fb1c00aa7.jpg
#   inflating: train_v2/fb1c0758c.jpg
#   inflating: train_v2/fb1c489a6.jpg
#   inflating: train_v2/fb1cd579b.jpg
#   inflating: train_v2/fb1d162fd.jpg
#   inflating: train_v2/fb1d2a1cc.jpg
#   inflating: train_v2/fb1d70f39.jpg
#   inflating: train_v2/fb1d70fa2.jpg
#   inflating: train_v2/fb1d9a992.jpg
#   inflating: train_v2/fb1dac2c2.jpg
#   inflating: train_v2/fb1dc8119.jpg
#   inflating: train_v2/fb1e8a403.jpg
#   inflating: train_v2/fb1eb1ed8.jpg
#   inflating: train_v2/fb1eb2f29.jpg
# ...
#   inflating: train_v2/ff6a9bc74.jpg
#   inflating: train_v2/ff6af69bb.jpg
#   inflating: train_v2/ff6bc2667.jpg
#   inflating: train_v2/ff6bda1f0.jpg
#   inflating: train_v2/ff6c45db9.jpg
#   inflating: train_v2/ff6ca3ad7.jpg
#   inflating: train_v2/ff6d2990a.jpg
#   inflating: train_v2/ff6d410c0.jpg
#   inflating: train_v2/ff6d7717d.jpg
#   inflating: train_v2/ff6dcde1c.jpg
#   inflating: train_v2/ff6df12de.jpg
#   inflating: train_v2/ff6e5641c.jpg
#   inflating: train_v2/ff6f8e47d.jpg
#   inflating: train_v2/ff702086d.jpg
#   inflating: train_v2/ff70a294e.jpg
#   inflating: train_v2/ff70b317e.jpg
#   inflating: train_v2/ff70ec802.jpg
#   inflating: train_v2/ff70f19cf.jpg
#   inflating: train_v2/ff71ddc81.jpg
#   inflating: train_v2/ff725cd06.jpg
#   inflating: train_v2/ff7271e87.jpg
#   inflating: train_v2/ff72b29c5.jpg
#   inflating: train_v2/ff7379231.jpg
#   inflating: train_v2/ff73ed159.jpg
#   inflating: train_v2/ff7425f26.jpg
#   inflating: train_v2/ff7450a1a.jpg
#   inflating: train_v2/ff74649d0.jpg
#   inflating: train_v2/ff746e328.jpg
#   inflating: train_v2/ff74d1782.jpg
#   inflating: train_v2/ff74e17ee.jpg
#   inflating: train_v2/ff7516045.jpg
#   inflating: train_v2/ff753344d.jpg
#   inflating: train_v2/ff7549527.jpg
#   inflating: train_v2/ff758bf14.jpg
#   inflating: train_v2/ff75ff680.jpg
#   inflating: train_v2/ff7683c2d.jpg
#   inflating: train_v2/ff77371b4.jpg
#   inflating: train_v2/ff774db80.jpg
#   inflating: train_v2/ff7755607.jpg
#   inflating: train_v2/ff78473f4.jpg
#   inflating: train_v2/ff7851f6c.jpg
#   inflating: train_v2/ff78bbebd.jpg
#   inflating: train_v2/ff78d6bf9.jpg
#   inflating: train_v2/ff791565c.jpg
#   inflating: train_v2/ff793d628.jpg
#   inflating: train_v2/ff79bcf7a.jpg
#   inflating: train_v2/ff79c9b9f.jpg
#   inflating: train_v2/ff79f40a8.jpg
#   inflating: train_v2/ff7a5cbf0.jpg
#   inflating: train_v2/ff7ac7f3c.jpg
#   inflating: train_v2/ff7b0826b.jpg
#   inflating: train_v2/ff7b0a53c.jpg
#   inflating: train_v2/ff7b61afb.jpg
#   inflating: train_v2/ff7bec47b.jpg
#   inflating: train_v2/ff7bf1b9f.jpg
#   inflating: train_v2/ff7c6f061.jpg
#   inflating: train_v2/ff7c769bf.jpg
#   inflating: train_v2/ff7caf167.jpg
#   inflating: train_v2/ff7cc4126.jpg
#   inflating: train_v2/ff7ce8b82.jpg
#   inflating: train_v2/ff7d18aa2.jpg
#   inflating: train_v2/ff7d2271c.jpg
#   inflating: train_v2/ff7d333f4.jpg
#   inflating: train_v2/ff7d9038d.jpg
#   inflating: train_v2/ff7db95ff.jpg
#   inflating: train_v2/ff7e20160.jpg
#   inflating: train_v2/ff7e85dfd.jpg
#   inflating: train_v2/ff7fab720.jpg
#   inflating: train_v2/ff7ff5eab.jpg
#   inflating: train_v2/ff8083133.jpg
#   inflating: train_v2/ff80890e1.jpg
#   inflating: train_v2/ff808d62d.jpg
#   inflating: train_v2/ff81be18c.jpg
#   inflating: train_v2/ff82168c6.jpg
#   inflating: train_v2/ff826b831.jpg
#   inflating: train_v2/ff82c74ba.jpg
#   inflating: train_v2/ff83ac85a.jpg
#   inflating: train_v2/ff83ead39.jpg
#   inflating: train_v2/ff8407429.jpg
#   inflating: train_v2/ff84d9ed4.jpg
#   inflating: train_v2/ff855c57a.jpg
#   inflating: train_v2/ff86c30f5.jpg
#   inflating: train_v2/ff873bf70.jpg
#   inflating: train_v2/ff8792045.jpg
#   inflating: train_v2/ff87d83de.jpg
#   inflating: train_v2/ff88c1d15.jpg
#   inflating: train_v2/ff890d001.jpg
#   inflating: train_v2/ff8946319.jpg
#   inflating: train_v2/ff898a59c.jpg
#   inflating: train_v2/ff8abc7e8.jpg
#   inflating: train_v2/ff8ac5adc.jpg
#   inflating: train_v2/ff8ace074.jpg
#   inflating: train_v2/ff8b6ef8a.jpg
#   inflating: train_v2/ff8be43bc.jpg
#   inflating: train_v2/ff8bf866a.jpg
#   inflating: train_v2/ff8c426ba.jpg
#   inflating: train_v2/ff8c71c8d.jpg
#   inflating: train_v2/ff8d0f2cc.jpg
#   inflating: train_v2/ff8d5e6c7.jpg
#   inflating: train_v2/ff8d90c20.jpg
#   inflating: train_v2/ff8d9ead8.jpg
#   inflating: train_v2/ff8dd5dcf.jpg
#   inflating: train_v2/ff8e35b80.jpg
#   inflating: train_v2/ff8fc08f7.jpg
#   inflating: train_v2/ff8fdeddf.jpg
#   inflating: train_v2/ff9024ba1.jpg
#   inflating: train_v2/ff9028a82.jpg
#   inflating: train_v2/ff903a38c.jpg
#   inflating: train_v2/ff90a9c38.jpg
#   inflating: train_v2/ff90c7fe5.jpg
#   inflating: train_v2/ff9101773.jpg
#   inflating: train_v2/ff91bece1.jpg
#   inflating: train_v2/ff91d6c67.jpg
#   inflating: train_v2/ff9252791.jpg
#   inflating: train_v2/ff9264676.jpg
#   inflating: train_v2/ff92e63f9.jpg
#   inflating: train_v2/ff935bcf0.jpg
#   inflating: train_v2/ff93c4203.jpg
#   inflating: train_v2/ff93f8943.jpg
#   inflating: train_v2/ff94b39ce.jpg
#   inflating: train_v2/ff9564713.jpg
#   inflating: train_v2/ff95ee15f.jpg
#   inflating: train_v2/ff96a9eec.jpg
#   inflating: train_v2/ff97064f7.jpg
#   inflating: train_v2/ff970c9de.jpg
#   inflating: train_v2/ff9727bfc.jpg
#   inflating: train_v2/ff974c36b.jpg
#   inflating: train_v2/ff97ebfd9.jpg
#   inflating: train_v2/ff9800c38.jpg
#   inflating: train_v2/ff981a6af.jpg
#   inflating: train_v2/ff98308ec.jpg
#   inflating: train_v2/ff986a4ee.jpg
#   inflating: train_v2/ff98aa454.jpg
#   inflating: train_v2/ff9900aae.jpg
#   inflating: train_v2/ff9a9fb1a.jpg
#   inflating: train_v2/ff9ab42e8.jpg
#   inflating: train_v2/ff9ad50ec.jpg
#   inflating: train_v2/ff9b2870f.jpg
#   inflating: train_v2/ff9b87d91.jpg
#   inflating: train_v2/ff9b8d74f.jpg
#   inflating: train_v2/ff9bc8ad7.jpg
#   inflating: train_v2/ff9bc9c09.jpg
#   inflating: train_v2/ff9beaed6.jpg
#   inflating: train_v2/ff9c704e8.jpg
#   inflating: train_v2/ff9c72120.jpg
#   inflating: train_v2/ff9cd53bb.jpg
#   inflating: train_v2/ff9d0bf1a.jpg
#   inflating: train_v2/ff9d2a53e.jpg
#   inflating: train_v2/ff9d9c109.jpg
#   inflating: train_v2/ff9e1619f.jpg
#   inflating: train_v2/ff9e1c5a5.jpg
#   inflating: train_v2/ff9e62590.jpg
#   inflating: train_v2/ff9e9a86e.jpg
#   inflating: train_v2/ff9f39fc8.jpg
#   inflating: train_v2/ff9f6f299.jpg
#   inflating: train_v2/ffa01da76.jpg
#   inflating: train_v2/ffa0573cb.jpg
#   inflating: train_v2/ffa0d58cb.jpg
#   inflating: train_v2/ffa0d62a4.jpg
#   inflating: train_v2/ffa1102e3.jpg
#   inflating: train_v2/ffa18f09d.jpg
#   inflating: train_v2/ffa24d62d.jpg
#   inflating: train_v2/ffa2718e2.jpg
#   inflating: train_v2/ffa36ad4c.jpg
#   inflating: train_v2/ffa569440.jpg
#   inflating: train_v2/ffa5d289e.jpg
#   inflating: train_v2/ffa6115c2.jpg
#   inflating: train_v2/ffa710585.jpg
#   inflating: train_v2/ffa715df2.jpg
#   inflating: train_v2/ffa71fd8e.jpg
#   inflating: train_v2/ffa73c04d.jpg
#   inflating: train_v2/ffa79fd64.jpg
#   inflating: train_v2/ffa7cb811.jpg
#   inflating: train_v2/ffa8e5536.jpg
#   inflating: train_v2/ffa8ebcca.jpg
#   inflating: train_v2/ffa9569bf.jpg
#   inflating: train_v2/ffa976772.jpg
#   inflating: train_v2/ffa98910d.jpg
#   inflating: train_v2/ffaa74e82.jpg
#   inflating: train_v2/ffab19e1f.jpg
#   inflating: train_v2/ffabdd14e.jpg
#   inflating: train_v2/ffac3e86e.jpg
#   inflating: train_v2/ffac57fd1.jpg
#   inflating: train_v2/ffacbee38.jpg
#   inflating: train_v2/ffad06c1b.jpg
#   inflating: train_v2/ffadb87a5.jpg
#   inflating: train_v2/ffadedc44.jpg
#   inflating: train_v2/ffae21688.jpg
#   inflating: train_v2/ffae6c2e5.jpg
#   inflating: train_v2/ffae80d6d.jpg
#   inflating: train_v2/ffaeb8838.jpg
#   inflating: train_v2/ffaf232ff.jpg
#   inflating: train_v2/ffaf289fa.jpg
#   inflating: train_v2/ffb06c920.jpg
#   inflating: train_v2/ffb0e262f.jpg
#   inflating: train_v2/ffb132944.jpg
#   inflating: train_v2/ffb160638.jpg
#   inflating: train_v2/ffb18b8b8.jpg
#   inflating: train_v2/ffb21a39c.jpg
#   inflating: train_v2/ffb24472e.jpg
#   inflating: train_v2/ffb348cbf.jpg
#   inflating: train_v2/ffb3cc3b0.jpg
#   inflating: train_v2/ffb3d7e50.jpg
#   inflating: train_v2/ffb3eb4d1.jpg
#   inflating: train_v2/ffb44f8b5.jpg
#   inflating: train_v2/ffb4c9f6a.jpg
#   inflating: train_v2/ffb52b4a4.jpg
#   inflating: train_v2/ffb5490bf.jpg
#   inflating: train_v2/ffb60321e.jpg
#   inflating: train_v2/ffb634518.jpg
#   inflating: train_v2/ffb6af57c.jpg
#   inflating: train_v2/ffb7128a7.jpg
#   inflating: train_v2/ffb76bacb.jpg
#   inflating: train_v2/ffb7b125a.jpg
#   inflating: train_v2/ffb7b173e.jpg
#   inflating: train_v2/ffb7cbe04.jpg
#   inflating: train_v2/ffb842f24.jpg
#   inflating: train_v2/ffb86de7a.jpg
#   inflating: train_v2/ffb88b5ab.jpg
#   inflating: train_v2/ffb8d4d20.jpg
#   inflating: train_v2/ffb9beeb3.jpg
#   inflating: train_v2/ffba3c6ad.jpg
#   inflating: train_v2/ffba44946.jpg
#   inflating: train_v2/ffbaa7de1.jpg
#   inflating: train_v2/ffbac8385.jpg
#   inflating: train_v2/ffbafc17f.jpg
#   inflating: train_v2/ffbb699d6.jpg
#   inflating: train_v2/ffbb7d5dc.jpg
#   inflating: train_v2/ffbbb557c.jpg
#   inflating: train_v2/ffbbdef34.jpg
#   inflating: train_v2/ffbcb81c4.jpg
#   inflating: train_v2/ffbd295da.jpg
#   inflating: train_v2/ffbe01d43.jpg
#   inflating: train_v2/ffbe6391e.jpg
#   inflating: train_v2/ffbe8c1ed.jpg
#   inflating: train_v2/ffbebfb80.jpg
#   inflating: train_v2/ffbf0e1aa.jpg
#   inflating: train_v2/ffbf76a8c.jpg
#   inflating: train_v2/ffbf7ecf7.jpg
#   inflating: train_v2/ffbfe5064.jpg
#   inflating: train_v2/ffc00cde1.jpg
#   inflating: train_v2/ffc017ec1.jpg
#   inflating: train_v2/ffc01a9b5.jpg
#   inflating: train_v2/ffc093132.jpg
#   inflating: train_v2/ffc0c85d6.jpg
#   inflating: train_v2/ffc0f0f82.jpg
#   inflating: train_v2/ffc1a7db5.jpg
#   inflating: train_v2/ffc1c325d.jpg
#   inflating: train_v2/ffc248918.jpg
#   inflating: train_v2/ffc2a6de6.jpg
#   inflating: train_v2/ffc2b4c3b.jpg
#   inflating: train_v2/ffc2cfc21.jpg
#   inflating: train_v2/ffc31f567.jpg
#   inflating: train_v2/ffc40c697.jpg
#   inflating: train_v2/ffc4209ad.jpg
#   inflating: train_v2/ffc4988e3.jpg
#   inflating: train_v2/ffc4a4a05.jpg
#   inflating: train_v2/ffc548d1f.jpg
#   inflating: train_v2/ffc5919d8.jpg
#   inflating: train_v2/ffc618880.jpg
#   inflating: train_v2/ffc6256eb.jpg
#   inflating: train_v2/ffc64849c.jpg
#   inflating: train_v2/ffc69fd86.jpg
#   inflating: train_v2/ffc6d6dcc.jpg
#   inflating: train_v2/ffc706013.jpg
#   inflating: train_v2/ffc717310.jpg
#   inflating: train_v2/ffc73f4e9.jpg
#   inflating: train_v2/ffc7516e0.jpg
#   inflating: train_v2/ffc7cd283.jpg
#   inflating: train_v2/ffc848f0a.jpg
#   inflating: train_v2/ffc90b7c8.jpg
#   inflating: train_v2/ffc9bd56d.jpg
#   inflating: train_v2/ffca90231.jpg
#   inflating: train_v2/ffca90af4.jpg
#   inflating: train_v2/ffcbc664f.jpg
#   inflating: train_v2/ffcc5857f.jpg
#   inflating: train_v2/ffcc97a96.jpg
#   inflating: train_v2/ffccbd846.jpg
#   inflating: train_v2/ffcccf6ce.jpg
#   inflating: train_v2/ffcd0b14f.jpg
#   inflating: train_v2/ffcda19e7.jpg
#   inflating: train_v2/ffcdf912b.jpg
#   inflating: train_v2/ffce63261.jpg
#   inflating: train_v2/ffcf51907.jpg
#   inflating: train_v2/ffd012f4a.jpg
#   inflating: train_v2/ffd0a9c5a.jpg
#   inflating: train_v2/ffd1139d7.jpg
#   inflating: train_v2/ffd122fb1.jpg
#   inflating: train_v2/ffd12ac28.jpg
#   inflating: train_v2/ffd164cf6.jpg
#   inflating: train_v2/ffd16d98b.jpg
#   inflating: train_v2/ffd1999b4.jpg
#   inflating: train_v2/ffd1b32d9.jpg
#   inflating: train_v2/ffd1c76e6.jpg
#   inflating: train_v2/ffd20fd4f.jpg
#   inflating: train_v2/ffd23d459.jpg
#   inflating: train_v2/ffd2583e4.jpg
#   inflating: train_v2/ffd25e290.jpg
#   inflating: train_v2/ffd2a59ec.jpg
#   inflating: train_v2/ffd2e5476.jpg
#   inflating: train_v2/ffd345be1.jpg
#   inflating: train_v2/ffd45be26.jpg
#   inflating: train_v2/ffd45c94b.jpg
#   inflating: train_v2/ffd48d047.jpg
#   inflating: train_v2/ffd532d43.jpg
#   inflating: train_v2/ffd5a5e21.jpg
#   inflating: train_v2/ffd5c101e.jpg
#   inflating: train_v2/ffd692b37.jpg
#   inflating: train_v2/ffd6a9ac7.jpg
#   inflating: train_v2/ffd75fe4c.jpg
#   inflating: train_v2/ffd7a32e9.jpg
#   inflating: train_v2/ffd88aa3c.jpg
#   inflating: train_v2/ffd89522b.jpg
#   inflating: train_v2/ffd92fed4.jpg
#   inflating: train_v2/ffd94c0ef.jpg
#   inflating: train_v2/ffd98caa2.jpg
#   inflating: train_v2/ffd9998b5.jpg
#   inflating: train_v2/ffda7ddfa.jpg
#   inflating: train_v2/ffda9012d.jpg
#   inflating: train_v2/ffdae92b5.jpg
#   inflating: train_v2/ffdb36906.jpg
#   inflating: train_v2/ffdc4c4ac.jpg
#   inflating: train_v2/ffdc6f2ce.jpg
#   inflating: train_v2/ffdd62e14.jpg
#   inflating: train_v2/ffde43c05.jpg
#   inflating: train_v2/ffdecffbc.jpg
#   inflating: train_v2/ffdfc69dc.jpg
#   inflating: train_v2/ffdfcf56a.jpg
#   inflating: train_v2/ffdfe7893.jpg
#   inflating: train_v2/ffe0de6ab.jpg
#   inflating: train_v2/ffe1b643a.jpg
#   inflating: train_v2/ffe1d7e9a.jpg
#   inflating: train_v2/ffe267d90.jpg
#   inflating: train_v2/ffe2bd99c.jpg
#   inflating: train_v2/ffe2c660e.jpg
#   inflating: train_v2/ffe2ee2ef.jpg
#   inflating: train_v2/ffe2fcd0e.jpg
#   inflating: train_v2/ffe349a88.jpg
#   inflating: train_v2/ffe3cb461.jpg
#   inflating: train_v2/ffe3ee83a.jpg
#   inflating: train_v2/ffe49dbce.jpg
#   inflating: train_v2/ffe51c315.jpg
#   inflating: train_v2/ffe5664d9.jpg
#   inflating: train_v2/ffe5b6aba.jpg
#   inflating: train_v2/ffe627bb3.jpg
#   inflating: train_v2/ffe65f43a.jpg
#   inflating: train_v2/ffe69c1ab.jpg
#   inflating: train_v2/ffe7061a6.jpg
#   inflating: train_v2/ffe744a4c.jpg
#   inflating: train_v2/ffe7ab0c7.jpg
#   inflating: train_v2/ffe7c6309.jpg
#   inflating: train_v2/ffe89d4cb.jpg
#   inflating: train_v2/ffe932f98.jpg
#   inflating: train_v2/ffe948ba8.jpg
#   inflating: train_v2/ffe98da77.jpg
#   inflating: train_v2/ffe9a97f2.jpg
#   inflating: train_v2/ffe9c109c.jpg
#   inflating: train_v2/ffea7dc68.jpg
#   inflating: train_v2/ffea9a5ba.jpg
#   inflating: train_v2/ffeb8c3e6.jpg
#   inflating: train_v2/ffebdf436.jpg
#   inflating: train_v2/ffec2d694.jpg
#   inflating: train_v2/ffec95ea3.jpg
#   inflating: train_v2/ffecdeb53.jpg
#   inflating: train_v2/ffed6e788.jpg
#   inflating: train_v2/ffed9001d.jpg
#   inflating: train_v2/ffee0cf47.jpg
#   inflating: train_v2/ffee22298.jpg
#   inflating: train_v2/ffee378e9.jpg
#   inflating: train_v2/ffeeb009b.jpg
#   inflating: train_v2/ffef7c3f3.jpg
#   inflating: train_v2/ffef9b8a7.jpg
#   inflating: train_v2/ffef9c68d.jpg
#   inflating: train_v2/fff0464c0.jpg
#   inflating: train_v2/fff05f8af.jpg
#   inflating: train_v2/fff139aa6.jpg
#   inflating: train_v2/fff1bdeea.jpg
#   inflating: train_v2/fff24b056.jpg
#   inflating: train_v2/fff30ef25.jpg
#   inflating: train_v2/fff3220c3.jpg
#   inflating: train_v2/fff37ad60.jpg
#   inflating: train_v2/fff3a3a1a.jpg
#   inflating: train_v2/fff422ae3.jpg
#   inflating: train_v2/fff4b225c.jpg
#   inflating: train_v2/fff509e15.jpg
#   inflating: train_v2/fff529a0e.jpg
#   inflating: train_v2/fff60f4bc.jpg
#   inflating: train_v2/fff67c31a.jpg
#   inflating: train_v2/fff75d91a.jpg
#   inflating: train_v2/fff77c602.jpg
#   inflating: train_v2/fff8125de.jpg
#   inflating: train_v2/fff89e163.jpg
#   inflating: train_v2/fff8ced35.jpg
#   inflating: train_v2/fff909871.jpg
#   inflating: train_v2/fff9395dc.jpg
#   inflating: train_v2/fff998ae9.jpg
#   inflating: train_v2/fff9aa012.jpg
#   inflating: train_v2/fffa15273.jpg
#   inflating: train_v2/fffa44607.jpg
#   inflating: train_v2/fffa5960e.jpg
#   inflating: train_v2/fffa80c97.jpg
#   inflating: train_v2/fffa926c8.jpg
#   inflating: train_v2/fffb2924f.jpg
#   inflating: train_v2/fffb36a47.jpg
#   inflating: train_v2/fffbb804d.jpg
#   inflating: train_v2/fffc0ade1.jpg
#   inflating: train_v2/fffc12f8c.jpg
#   inflating: train_v2/fffc6b811.jpg
#   inflating: train_v2/fffcb6464.jpg
#   inflating: train_v2/fffcd0cf7.jpg
#   inflating: train_v2/fffcda6d6.jpg
#   inflating: train_v2/fffd924fb.jpg
#   inflating: train_v2/fffdd2377.jpg
#   inflating: train_v2/fffe4c385.jpg
#   inflating: train_v2/fffe4fa23.jpg
#   inflating: train_v2/fffe646cf.jpg
#   inflating: train_v2/fffedbb6b.jpg
#   inflating: train_v2/ffff2aa57.jpg
#   inflating: train_v2/ffff6e525.jpg
#   inflating: train_v2/ffffc50b4.jpg
#   inflating: train_v2/ffffe97f3.jpg

# %%
DATA_DIR = '/content'

# %%
! mkdir /content/oussama
# Out:
# mkdir: cannot create directory ‘/content/oussama’: File exists

# %%
ROOT_DIR = '/content/oussama'

# %%
# !git clone https://www.github.com/matterport/Mask_RCNN.git
os.chdir('Mask_RCNN')
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
# !pip uninstall keras -y
# !pip uninstall keras-nightly -y
# !pip uninstall keras-Preprocessing -y
# !pip uninstall keras-vis -y
# !pip uninstall tensorflow -y
# !pip uninstall h5py -y
# !pip install tensorflow==1.13.1
# !pip install keras==2.0.8
# !pip install h5py==2.10.0
# Out:
# Found existing installation: keras 2.8.0
# Uninstalling keras-2.8.0:
#   Successfully uninstalled keras-2.8.0
# WARNING: Skipping keras-nightly as it is not installed.
# Found existing installation: Keras-Preprocessing 1.1.2
# Uninstalling Keras-Preprocessing-1.1.2:
#   Successfully uninstalled Keras-Preprocessing-1.1.2
# Found existing installation: keras-vis 0.4.1
# Uninstalling keras-vis-0.4.1:
#   Successfully uninstalled keras-vis-0.4.1
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# Found existing installation: h5py 3.1.0
# Uninstalling h5py-3.1.0:
#   Successfully uninstalled h5py-3.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.13.1
#   Downloading tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6 MB)
#      |████████████████████████████████| 92.6 MB 1.2 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.37.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.8.1)
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.0 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.21.6)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
#      |████████████████████████████████| 367 kB 56.0 MB/s
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.5.3)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.2 MB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (3.17.3)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 38.0 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.46.3)
# Collecting h5py
#   Downloading h5py-3.7.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 39.8 MB/s
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.8.0)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Installing collected packages: mock, h5py, tensorflow-estimator, tensorboard, keras-preprocessing, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.13.1 which is incompatible.
# Successfully installed h5py-3.7.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras==2.0.8
#   Downloading Keras-2.0.8-py2.py3-none-any.whl (276 kB)
#      |████████████████████████████████| 276 kB 6.2 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.0.8) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.0.8) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.0.8) (3.13)
# Installing collected packages: keras
# Successfully installed keras-2.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 5.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.21.6)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.7.0
#     Uninstalling h5py-3.7.0:
#       Successfully uninstalled h5py-3.7.0
# Successfully installed h5py-2.10.0

# %%
sys.path.append(os.path.join('/content/Mask_RCNN', 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'train_v2')
test_dicom_dir = os.path.join(DATA_DIR, 'test_v2')

# %%
# !wget --quiet https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5
# !ls -lh mask_rcnn_coco.h5

COCO_WEIGHTS_PATH = "mask_rcnn_coco.h5"
# Out:
# -rw-r--r-- 1 root root 246M Dec  6  2021 mask_rcnn_coco.h5

# %%
class DetectorConfig(Config):    
    # Give the configuration a recognizable name  
    NAME = 'airbus'
    
    GPU_COUNT = 1
    IMAGES_PER_GPU = 9
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background and ship classes
    
    IMAGE_MIN_DIM = 384
    IMAGE_MAX_DIM = 384
    RPN_ANCHOR_SCALES = (8, 16, 32, 64)
    TRAIN_ROIS_PER_IMAGE = 64
    MAX_GT_INSTANCES = 14
    DETECTION_MAX_INSTANCES = 10
    DETECTION_MIN_CONFIDENCE = 0.95
    DETECTION_NMS_THRESHOLD = 0.0
    
    STEPS_PER_EPOCH = 15 
    VALIDATION_STEPS = 10 
    
    ## balance out losses
    LOSS_WEIGHTS = {
        "rpn_class_loss": 30.0,
        "rpn_bbox_loss": 0.8,
        "mrcnn_class_loss": 6.0,
        "mrcnn_bbox_loss": 1.0,
        "mrcnn_mask_loss": 1.2
    }
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     9
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        10
# DETECTION_MIN_CONFIDENCE       0.95
# DETECTION_NMS_THRESHOLD        0.0
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 9
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  384
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  384
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [384 384   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 30.0, 'rpn_bbox_loss': 0.8, 'mrcnn_class_loss': 6.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.2}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               14
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           airbus
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                15
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           64
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               10
# WEIGHT_DECAY                   0.0001

# %%
import os
import numpy as np
import pandas as pd
from skimage.io import imread
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from skimage.segmentation import mark_boundaries
from skimage.util import montage
from skimage.morphology import binary_opening, disk, label
import gc; gc.enable() # memory is tight

# %%
montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1) # to rgb function

def multi_rle_encode(img, **kwargs):
    '''
    Encode connected regions as separated masks
    '''
    labels = label(img)
    if img.ndim > 2:
        return [rle_encode(np.sum(labels==k, axis=2), **kwargs) for k in np.unique(labels[labels>0])]
    else:
        return [rle_encode(labels==k, **kwargs) for k in np.unique(labels[labels>0])]

# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_encode(img, min_max_threshold=1e-3, max_mean_threshold=None): # raster to rle coding 
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    if np.max(img) < min_max_threshold:
        return '' ## no need to encode if it's all zeros
    if max_mean_threshold and np.mean(img) > max_mean_threshold:
        return '' ## ignore overfilled mask
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)): # rle coding to raster
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list):
    # Take the individual ship masks and create a single mask array for all ships
    all_masks = np.zeros((768, 768), dtype = np.uint8)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks |= rle_decode(mask)
    return all_masks

def masks_as_color(in_mask_list):
    # Take the individual ship masks and create a color mask array for each ships
    all_masks = np.zeros((768, 768), dtype = np.float)
    scale = lambda x: (len(in_mask_list)+x+1) / (len(in_mask_list)*2) ## scale the heatmap image to shift 
    for i,mask in enumerate(in_mask_list):
        if isinstance(mask, str):
            all_masks[:,:] += scale(i) * rle_decode(mask)
    return all_masks

# %%
from PIL import Image
from sklearn.model_selection import train_test_split

# hatalı resim listesi
exclude_list = ['6384c3e78.jpg','13703f040.jpg', '14715c06d.jpg',  '33e0ff2d5.jpg',
                '4d4e09f2a.jpg', '877691df8.jpg', '8b909bb20.jpg', 'a8d99130e.jpg', 
                'ad55c3143.jpg', 'c8260c541.jpg', 'd6c7f17c7.jpg', 'dc3e7c901.jpg',
                'e44dffe88.jpg', 'ef87bad36.jpg', 'f083256d8.jpg'] #corrupted images

train_names = [f for f in os.listdir(train_dicom_dir) if f not in exclude_list]
test_names = [f for f in os.listdir(test_dicom_dir) if f not in exclude_list]

print(len(train_names), len(test_names))
# Out:
# 192555 15606

# %%
# training dataset
SEGMENTATION = DATA_DIR + '/train_ship_segmentations_v2.csv'
anns = pd.read_csv(SEGMENTATION)
anns.head()
# Out:
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  0001124c7.jpg                                                NaN
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...

# %%
train_names = anns[anns.EncodedPixels.notnull()].ImageId.unique().tolist()
print("Uniq image list containing ships:",np.shape(train_names))

test_size = config.VALIDATION_STEPS * config.IMAGES_PER_GPU # 10*9
image_fps_train, image_fps_val = train_test_split(train_names, test_size=test_size, random_state=42)

print("train:",len(image_fps_train), "val:",len(image_fps_val), "test:",len(test_names))
# Out:
# Uniq image list containing ships: (42556,)
# train: 42466 val: 90 test: 15606

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training our dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('ship', 1, 'Ship')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations.query('ImageId=="' + fp + '"')['EncodedPixels']
            self.add_image('ship', image_id=i, path=os.path.join(train_dicom_dir, fp), 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        image = imread(fp)
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
#         print(image_id, annotations)
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                mask[:, :, i] = rle_decode(a)
                class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %%
image_fps, image_annotations = train_names, anns
print("Uniq image list containing ships:",np.shape(image_fps))
print("Train ship segmentations csv file:",np.shape(image_annotations))
# Out:
# Uniq image list containing ships: (42556,)
# Train ship segmentations csv file: (231723, 2)

# %%
ds = imread(os.path.join(train_dicom_dir, image_fps[0])) # read  image from filepath 
plt.imshow(ds)

# Original image size: 768 x 768
ORIG_SIZE = ds.shape[0]
print("Image original size:",ORIG_SIZE)
# Out:
# Image original size: 768

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-95d56b35b190> in <module>()
#       1 # prepare the training dataset
# ----> 2 dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
#       3 dataset_train.prepare()
#
# <ipython-input-19-91dc107c601a> in __init__(self, image_fps, image_annotations, orig_height, orig_width)
#      11         # add images
#      12         for i, fp in enumerate(image_fps):
# ---> 13             annotations = image_annotations.query('ImageId=="' + fp + '"')['EncodedPixels']
#      14             self.add_image('ship', image_id=i, path=os.path.join(train_dicom_dir, fp),
#      15                            annotations=annotations, orig_height=orig_height, orig_width=orig_width)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4058         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4059         kwargs["target"] = None
# -> 4060         res = self.eval(expr, **kwargs)
#    4061
#    4062         try:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4189         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    4190
# -> 4191         return _eval(expr, inplace=inplace, **kwargs)
#    4192
#    4193     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     346         )
#     347
# --> 348         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     349
#     350         # construct the engine and evaluate the parsed expression
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     804         self.parser = parser
#     805         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 806         self.terms = self.parse()
#     807
#     808     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in parse(self)
#     823         Parse an expression.
#     824         """
# --> 825         return self._visitor.visit(self.expr)
#     826
#     827     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     415             raise SyntaxError("only a single expression is allowed")
#     416         expr = node.body[0]
# --> 417         return self.visit(expr, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
# --> 420         return self.visit(node.value, **kwargs)
#     421
#     422     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     716             op = self.translate_In(ops[0])
#     717             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 718             return self.visit(binop)
#     719
#     720         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     532         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533         left, right = self._maybe_downcast_constants(left, right)
# --> 534         return self._maybe_evaluate_binop(op, op_class, left, right)
#     535
#     536     def visit_Div(self, node, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in _maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     518         if res.op in eval_in_python:
#     519             # "in"/"not in" ops are always evaluated in python
# --> 520             return self._maybe_eval(res, eval_in_python)
#     521         elif self.engine != "pytables":
#     522             if (
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py in _maybe_eval(self, binop, eval_in_python)
#     487         # call will be evaluated using isin (in python space)
#     488         return binop.evaluate(
# --> 489             self.env, self.engine, self.parser, self.term_type, eval_in_python
#     490         )
#     491
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/ops.py in evaluate(self, env, engine, parser, term_type, eval_in_python)
#     453             # base cases
#     454             if self.op in eval_in_python:
# --> 455                 res = self.func(left.value, right.value)
#     456             else:
#     457                 from pandas.core.computation.eval import eval
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/ops.py in _in(x, y)
#     269     """
#     270     try:
# --> 271         return x.isin(y)
#     272     except AttributeError:
#     273         if is_list_like(x):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in isin(self, values)
#    5023         dtype: bool
#    5024         """
# -> 5025         result = algorithms.isin(self._values, values)
#    5026         return self._constructor(result, index=self.index).__finalize__(
#    5027             self, method="isin"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in isin(comps, values)
#     522         f = htable.ismember
#     523
# --> 524     return f(comps, values)
#     525
#     526
#
# KeyboardInterrupt:

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()
